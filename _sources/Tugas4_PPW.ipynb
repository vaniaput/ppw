# %% [markdown]
# # CRAWLING PTA MANAJEMEN

# %%
# !pip install builtwith
# !pip install nltk
# !pip install Sastrawi
# !pip install pyspellchecker
# Out:
# Collecting builtwith
#   Downloading builtwith-1.3.4.tar.gz (34 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from builtwith) (1.17.0)
# Building wheels for collected packages: builtwith
#   Building wheel for builtwith (setup.py) ... done
#   Created wheel for builtwith: filename=builtwith-1.3.4-py3-none-any.whl size=36077 sha256=f29094318d557c75bce2f55da1b54274f018be4ddcd1f78c64e98f0d3d6bbe8c
#   Stored in directory: /root/.cache/pip/wheels/7f/2d/b2/606e3df914d4aeeab99c4a4e3e9a61673d2293c2e346db00c8
# Successfully built builtwith
# Installing collected packages: builtwith
# Successfully installed builtwith-1.3.4
# Requirement already satisfied: nltk in /usr/local/lib/python3.12/dist-packages (3.9.1)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from nltk) (8.2.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from nltk) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.12/dist-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from nltk) (4.67.1)
# Collecting Sastrawi
#   Downloading Sastrawi-1.0.1-py2.py3-none-any.whl.metadata (909 bytes)
# Downloading Sastrawi-1.0.1-py2.py3-none-any.whl (209 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.7/209.7 kB 11.8 MB/s eta 0:00:00
# Installing collected packages: Sastrawi
# Successfully installed Sastrawi-1.0.1
# Collecting pyspellchecker
#   Downloading pyspellchecker-0.8.3-py3-none-any.whl.metadata (9.5 kB)
# Downloading pyspellchecker-0.8.3-py3-none-any.whl (7.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 102.4 MB/s eta 0:00:00
# Installing collected packages: pyspellchecker
# Successfully installed pyspellchecker-0.8.3

# %% [markdown]
# ## 1. Crawling PTA

# %%
import builtwith

# Analisis teknologi yang digunakan
res = builtwith.parse('https://pta.trunojoyo.ac.id')
print(res)
# Out:
# {'web-servers': ['Nginx'], 'javascript-frameworks': ['jQuery', 'jQuery UI']}

# %% [markdown]
# ## Preprocessing Crawling PTA

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import sys
import re
import string
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from spellchecker import SpellChecker
from collections import Counter

# --- KONFIGURASI PRA-PEMROSESAN ---
# Kamus untuk normalisasi kata slang/kontraksi bahasa Indonesia
contractions_dict = {
    "gak": "tidak", "ga": "tidak", "nggak": "tidak", "enggak": "tidak", "ngga": "tidak", "gk": "tidak",
    "gue": "saya", "gw": "saya", "gua": "saya", "lu": "kamu", "loe": "kamu",
    "dah": "sudah", "udah": "sudah", "aja": "saja", "ajah": "saja",
    "yg": "yang", "utk": "untuk", "dlm": "dalam", "dr": "dari", "dg": "dengan",
    "jd": "jadi", "krn": "karena", "tp": "tetapi", "tapi": "tetapi",
    "banget": "sekali", "bgt": "sekali", "lg": "lagi",
}

# Daftar stopword bahasa Indonesia
stop_words = set([
    "yang", "di", "ke", "dan", "dari", "ini", "itu", "pada", "untuk",
    "dengan", "sebagai", "adalah", "merupakan", "dalam", "yaitu",
    "suatu", "sebuah", "dengan", "akan", "telah", "bisa", "agar",
    "dari", "oleh", "hal", "saat", "bahwa", "juga", "atau", "tidak",
    "namun", "tetapi", "kemudian", "sehingga", "serta", "guna",
    "seperti", "yaitu", "melalui", "terhadap", "seperti", "sejak",
    "saja", "hanya", "oleh", "pada", "sampai", "setelah", "sebelum",
    "karena", "maka", "tanpa"
])

# Inisialisasi Stemmer dari Sastrawi
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# Inisialisasi SpellChecker
spell = SpellChecker()

# --- FUNGSI-FUNGSI PRA-PEMROSESAN TERPISAH ---

def clean_base_text(text):
    """
    Fungsi dasar untuk membersihkan teks dari simbol, angka, dll.
    """
    if not isinstance(text, str):
        return ''

    text = text.lower()
    words = text.split()
    expanded_words = [contractions_dict.get(word, word) for word in words]
    text = ' '.join(expanded_words)

    text = re.sub(r'\d+', '', text)
    text = text.translate(str.maketrans('', '', string.punctuation))
    text = re.sub(r'\s+', ' ', text).strip()
    text = BeautifulSoup(text, "html.parser").get_text()

    return text

def tokenize_text(text):
    """
    # Proses: Tokenisasi
    # Memisahkan teks menjadi daftar kata (token).
    """
    return text.split()

def remove_stopwords(tokens):
    """
    # Proses: Penghapusan Kata Umum (Stopword)
    # Menghapus kata-kata yang tidak memiliki makna penting dalam analisis teks.
    """
    return [word for word in tokens if word not in stop_words]

def apply_stemming_and_lemmatization(tokens):
    """
    # Proses: Stemming dan Lematisasi
    # Mengubah kata berimbuhan menjadi kata dasar.
    """
    text = ' '.join(tokens)
    stemmed_text = stemmer.stem(text)
    return stemmed_text.split()

def correct_spelling(tokens):
    """
    # Proses: Cek Ejaan Pembakuan Kata
    # Memperbaiki ejaan kata.
    """
    corrected_words = [spell.correction(word) if spell.correction(word) is not None else word for word in tokens]
    return corrected_words

# --- FUNGSI-FUNGSI BANTUAN SCRAPING ---

def get_text_or_na(soup, selectors):
    """Mencoba beberapa selektor untuk menemukan teks, mengembalikan 'N/A' jika tidak ditemukan."""
    for selector in selectors:
        element = soup.select_one(selector)
        if element:
            text = element.get_text(strip=True)
            if text and text.strip():
                return text.strip()
    return 'N/A'

def get_data_from_span(soup, text_contains):
    """Mencari span yang berisi teks tertentu dan mengekstrak nama setelah titik dua."""
    span = soup.select_one(f'span:-soup-contains("{text_contains}")')
    if span:
        text = span.get_text(strip=True)
        if ':' in text:
            return text.split(':', 1)[1].strip()
    return 'N/A'

def get_abstract_robust(soup, keywords):
    """
    Mencari tag heading (b) yang teksnya mengandung salah satu dari kata kunci
    dan mengekstrak paragraf berikutnya.
    """
    for tag_b in soup.find_all('b'):
        tag_text = tag_b.get_text(strip=True)
        if any(keyword.lower() in tag_text.lower() for keyword in keywords):
            parent_div = tag_b.find_parent('div')
            if parent_div:
                next_div_sibling = parent_div.find_next_sibling('div')
                if next_div_sibling:
                    p_tag = next_div_sibling.find('p', align="justify")
                    if p_tag:
                        abstract_text = p_tag.get_text(strip=True)
                        if abstract_text:
                            return abstract_text
    return 'N/A'

def get_total_pages(soup):
    """
    Mengekstrak total jumlah halaman dari navigasi paginasi.
    """
    try:
        pagination = soup.select_one('ol.pagination')
        if pagination:
            last_page_li = pagination.select('li')[-1]
            last_page_link = last_page_li.select_one('a')
            if last_page_link and 'href' in last_page_link.attrs:
                url_path = last_page_link['href']
                return int(url_path.split('/')[-1])
    except (IndexError, ValueError, KeyError):
        pass
    return 1

# --- FUNGSI UTAMA SCRAPING ---

def scrape_manajemen_all_data():
    """
    Menjalankan proses scraping dan pra-pemrosesan data secara keseluruhan.
    """
    prodi_data = [
        {'name': 'Manajemen', 'url': 'https://pta.trunojoyo.ac.id/c_search/byprod/7'},
    ]

    all_scraped_data = {
        "penulis": [], "judul": [], "pembimbing_pertama": [], "pembimbing_kedua": [],
        "abstrak_indonesia_raw": [], "abstrak_inggris_raw": [],
        "abstrak_indonesia_clean": [], "abstrak_inggris_clean": [],
        "abstrak_indonesia_stopwords": [], "abstrak_inggris_stopwords": [],
        "abstrak_indonesia_stemmed": [], "abstrak_inggris_stemmed": [],
        "abstrak_indonesia_corrected": [], "abstrak_inggris_corrected": [],
        "prodi": []
    }

    total_data_count = 0
    print("--- MULAI PROSES SCRAPING Prodi Manajemen ---")

    for prodi in prodi_data:
        print(f"\nScraping data for program: {prodi['name']}")
        print("-" * 50)
        first_page_url = prodi['url']
        try:
            r = requests.get(first_page_url)
            r.raise_for_status()
            soup = BeautifulSoup(r.content, "html.parser")
            total_pages = get_total_pages(soup)
            print(f"Ditemukan {total_pages} halaman untuk {prodi['name']}")
        except requests.exceptions.RequestException as e:
            print(f"ERROR: Gagal mengambil halaman pertama untuk {prodi['name']}: {e}", file=sys.stderr)
            total_pages = 1

        for i in range(1, total_pages + 1):
            url = f"{prodi['url']}/{i}"
            try:
                r = requests.get(url)
                r.raise_for_status()
                soup = BeautifulSoup(r.content, "html.parser")
                jurnals = soup.select('li[data-cat="#luxury"]')

                if not jurnals:
                    print(f"Tidak ada jurnal lagi di halaman {i}. Berhenti untuk program ini.")
                    break

                for jurnal in jurnals:
                    jurnal_url = jurnal.select_one('a.gray.button')['href']
                    try:
                        response = requests.get(jurnal_url)
                        response.raise_for_status()
                        soup1 = BeautifulSoup(response.content, "html.parser")
                        isi = soup1.select_one('div#content_journal')
                        if isi:
                            judul = get_text_or_na(isi, ['a.title', 'b.title', 'h2.title'])
                            penulis = get_data_from_span(isi, "Penulis")
                            pembimbing_pertama = get_data_from_span(isi, "Dosen Pembimbing I")
                            pembimbing_kedua = get_data_from_span(isi, "Dosen Pembimbing II")
                            abstrak_indonesia = get_abstract_robust(isi, ["Abstraksi", "Abstrak"])
                            abstrak_inggris = get_abstract_robust(isi, ["Abstraction", "Abstract", "ABSTRACT"])

                            # --- Rangkaian Proses Pra-pemrosesan Teks ---

                            # 1. Pembersihan Dasar (lowercase, normalisasi slang, hapus simbol & angka)
                            clean_indonesia_text = clean_base_text(abstrak_indonesia)
                            clean_inggris_text = clean_base_text(abstrak_inggris)

                            # 2. Tokenisasi
                            tokens_indonesia = tokenize_text(clean_indonesia_text)
                            tokens_inggris = tokenize_text(clean_inggris_text)

                            # 3. Penghapusan Stopword
                            stopwords_indonesia_tokens = remove_stopwords(tokens_indonesia)
                            stopwords_inggris_tokens = remove_stopwords(tokens_inggris)

                            # 4. Stemming dan Lematisasi
                            stemmed_indonesia_tokens = apply_stemming_and_lemmatization(stopwords_indonesia_tokens)
                            stemmed_inggris_tokens = apply_stemming_and_lemmatization(stopwords_inggris_tokens)

                            # 5. Cek Ejaan (Pembakuan Kata)
                            corrected_indonesia_tokens = correct_spelling(stemmed_indonesia_tokens)
                            corrected_inggris_tokens = correct_spelling(stemmed_inggris_tokens)

                            # Menghitung frekuensi kata untuk abstrak yang sudah diproses
                            word_frequency_indonesia = Counter(stemmed_indonesia_tokens)
                            word_frequency_inggris = Counter(stemmed_inggris_tokens)

                            # Menambahkan data ke dictionary
                            all_scraped_data["penulis"].append(penulis)
                            all_scraped_data["judul"].append(judul)
                            all_scraped_data["pembimbing_pertama"].append(pembimbing_pertama)
                            all_scraped_data["pembimbing_kedua"].append(pembimbing_kedua)
                            all_scraped_data["prodi"].append(prodi['name'])
                            all_scraped_data["abstrak_indonesia_raw"].append(abstrak_indonesia)
                            all_scraped_data["abstrak_inggris_raw"].append(abstrak_inggris)
                            all_scraped_data["abstrak_indonesia_clean"].append(' '.join(tokens_indonesia))
                            all_scraped_data["abstrak_inggris_clean"].append(' '.join(tokens_inggris))
                            all_scraped_data["abstrak_indonesia_stopwords"].append(' '.join(stopwords_indonesia_tokens))
                            all_scraped_data["abstrak_inggris_stopwords"].append(' '.join(stopwords_inggris_tokens))
                            all_scraped_data["abstrak_indonesia_stemmed"].append(' '.join(stemmed_indonesia_tokens))
                            all_scraped_data["abstrak_inggris_stemmed"].append(' '.join(stemmed_inggris_tokens))
                            all_scraped_data["abstrak_indonesia_corrected"].append(' '.join(corrected_indonesia_tokens))
                            all_scraped_data["abstrak_inggris_corrected"].append(' '.join(corrected_inggris_tokens))

                            total_data_count += 1
                            print(f"\n--- Data #{total_data_count} ---")
                            print(f"Prodi: {prodi['name']}")
                            print(f"Penulis: {penulis}")
                            print(f"Judul: {judul}")
                            print(f"Pembimbing 1: {pembimbing_pertama}")
                            print(f"Pembimbing 2: {pembimbing_kedua}")
                            print(f"Abstrak (Raw): {abstrak_indonesia}")
                            print(f"Abstrak (Clean): {clean_indonesia_text}")
                            print(f"Abstrak (Stopwords Removed): {' '.join(stopwords_indonesia_tokens)}")
                            print(f"Abstrak (Stemmed): {' '.join(stemmed_indonesia_tokens)}")
                            print(f"Abstrak (Corrected): {' '.join(corrected_indonesia_tokens)}")

                            # Output frekuensi kata
                            print("\n--- Tokenisasi (Perhitungan Jumlah Kata) ---")
                            print(f"Frekuensi Kata (Indonesia): {word_frequency_indonesia}")
                            print(f"Frekuensi Kata (Inggris): {word_frequency_inggris}")
                            print("-------------------------------------------\n")

                    except Exception as e:
                        print(f"ERROR: Terjadi kesalahan saat memproses URL: {jurnal_url} - {e}", file=sys.stderr)

                time.sleep(1)

            except requests.exceptions.RequestException as e:
                print(f"ERROR: Gagal mengambil URL {url}: {e}", file=sys.stderr)
                continue

    df = pd.DataFrame(all_scraped_data)
    df.to_csv("pta_manajemen_all_preprocessing_steps.csv", index=False)
    print("\n---")
    print(f"Scraping selesai. Total data yang diambil: {total_data_count}")
    print("Data disimpan ke pta_manajemen_all_preprocessing_steps.csv")
    print("---")
    return df

# Menjalankan fungsi utama
scrape_manajemen_all_data()
# Out:
# Output streaming akan dipotong hingga 5000 baris terakhir.
# --- Data #407 ---
# Prodi: Manajemen
# Penulis: Subhan Juniarto
# Judul: PENGARUH PENGAWASAN PIMPINAN DAN MOTIVASI PEGAWAI TERHADAP KINERJA DINAS KEPENDUDUKAN DAN PENCATATAN SIPIL KABUPATEN SUMENEP
# Pembimbing 1: Drs. Ec. Mudji Kuswinarno, M. Si.
# Pembimbing 2: Faidal, SE., MM.
# Abstrak (Raw): Rumusan masalah dalam penelitian ini adalah (1) apakah Pengawasan Pimpinan berpengaruh terhadap Kinerja Dinas Kependudukan dan Pencatatan Sipil Kabupaten Sumenep? (2) apakah Motivasi Pegawai berpengaruh terhadap Kinerja Dinas Kependudukan dan Pencatatan Sipil Kabupaten Sumenep? (3) apakah Pengawasan Pimpinan dan Motivasi Pegawai berpengaruh terhadap Kinerja Dinas Kependudukan dan Pencatatan Sipil Kabupaten Sumenep? Penelitian ini menggunakan metode kuantitatif dimana populasi dan sampelnya adalah semua Pegawai Negeri Sipil Dinas Kependudukan dan Pencatatan Sipil Kabupaten Sumenep yang berjumlah 74 pegawai. Berdasarkan hasill penelitian, maka (1) Pengawasan Pimpinan tidak berpengaruh terhadap Kinerja Dinas Kependudukan dan Pencatatan Sipil Kabupaten Sumenep dengan nilaitHitungsebesar 0,298< ttabel 1,993 dan tingkatsignifikan 0,766> 0,05, sehingga H0 diterima dan H1 ditolak. (2) Motivasi Pegawai berpengaruh terhadap Kinerja Dinas Kependudukan dan Pencatatan Sipil Kabupaten Sumenep dengan tHitunguntukvariabelMotivasiPegawaisebesar 9,157 >ttabel 1,993 dan tingkatsignifikan0,000 < 0,05, sehingga H0 ditolak dan H1 diterima. (3) Pengawasan Pimpinan dan Motivasi Pegawai secara simultan berpengaruh terhadap Kinerja Dinas Kependudukan dan Pencatatan Sipil Kabupaten Sumenep dengan FHitung 73,961 >FTabel3,1257dantingkatsignifikan 0,000 < 0,05, sehingga H1diterimadan H¬0ditolak.
# Abstrak (Clean): rumusan masalah dalam penelitian ini adalah apakah pengawasan pimpinan berpengaruh terhadap kinerja dinas kependudukan dan pencatatan sipil kabupaten sumenep apakah motivasi pegawai berpengaruh terhadap kinerja dinas kependudukan dan pencatatan sipil kabupaten sumenep apakah pengawasan pimpinan dan motivasi pegawai berpengaruh terhadap kinerja dinas kependudukan dan pencatatan sipil kabupaten sumenep penelitian ini menggunakan metode kuantitatif dimana populasi dan sampelnya adalah semua pegawai negeri sipil dinas kependudukan dan pencatatan sipil kabupaten sumenep yang ber
#
# --- Tokenisasi (Perhitungan Jumlah Kata) ---
# Frekuensi Kata (Indonesia): Counter({'sipil': 8, 'dinas': 7, 'duduk': 7, 'catat': 7, 'kabupaten': 7, 'sumenep': 7, 'pengaruh': 6, 'kerja': 6, 'pegawai': 6, 'h': 5, 'awas': 4, 'pimpin': 4, 'motivasi': 4, 'teliti': 3, 'apakah': 3, 'tolak': 3, 'ttabel': 2, 'tingkatsignifikan': 2, 'terima': 2, 'rumus': 1, 'masalah': 1, 'guna': 1, 'metode': 1, 'kuantitatif': 1, 'mana': 1, 'populasi': 1, 'sampel': 1, 'semua': 1, 'negeri': 1, 'jumlah': 1, 'dasar': 1, 'hasill': 1, 'nilaithitungsebesar': 1, 'thitunguntukvariabelmotivasipegawaisebesar': 1, 'cara': 1, 'simultan': 1, 'fhitung': 1, 'ftabeldantingkatsignifikan': 1, 'hditerimadan': 1})
# Frekuensi Kata (Inggris): Counter({'of': 19, 'and': 15, 'the': 13, 'is': 10, 'population': 8, 'on': 7, 'departement': 7, 'civil': 7, 'registration': 7, 'an': 6, 'effect': 6, 'performance': 6, 'sumenep': 6, 'regency': 6, 'h': 6, 'have': 5, 'employee': 5, 'motivation': 5, 'employees': 5, 'does': 4, 'supervision': 4, 'leadership': 4, 'that': 4, 'government': 4, 'at': 4, 'so': 4, 'study': 3, 'with': 3, 'accepted': 3, 'rejected': 3, 'are': 2, 'tcount': 2, 'significant': 2, 'level': 2, 'statements': 1, 'research': 1, 'problem': 1, 'this': 1, 'sumenepregencythis': 1, 'uses': 1, 'quantitative': 1, 'method': 1, 'sample': 1, 'all': 1, 'wich': 1, 'amounted': 1, 'to': 1, 'based': 1, 'results': 1, 'not': 1, 'value': 1, 'has': 1, 'for': 1, 'variable': 1, 'ttable': 1, 'a': 1, 'simultaneously': 1, 'fcount': 1, 'ftable': 1})
# -------------------------------------------
#
#
# --- Data #408 ---
# Prodi: Manajemen
# Penulis: ARIS RASYIDITYO MUNIRHAD SU5RYO ADHIM
# Judul: PENGARUH KUALITAS PELAYANAN TERHADAP KEPUASAN PELANGGAN HOTEL AIR PANAS ALAM SONGGORITI
# Pembimbing 1: FATHOR A.S S.E., MM
# Pembimbing 2: YUDHI PRASETYA MADA S.E., MM
# Abstrak (Raw): Aris Rasyidityo Munirhad Suryo Adhim, Pengaruh kualitas pelayanan terhadap kepuasan pelanggan Hotel Air Panas Alam Songgoriti. Dibawah bimbingan dari Bapak Fathor A.S dan Yudi Prasetya Mada.
# Abstrak (Corrected): arms rasyidityo munirhad surya him pengaruh kualitas layman puts hangman hotel air pants alarm songgoriti away bombing back father as yuri prasetya made kualitas layman proud inti sara hotel debut but para sara biding hotel terms dingbat kualitas layman unsung rash puts lake bell slang kualitas layman salad sat factor pengaruh puts pelangganpenelitian juju tau pengaruh kualitas layman puts hangman hotel air pants alarm songgoriti variable independent elite kualitas layman dimensibukti fisk kehandalan day tanga jamie empty sedan variable dependent gun galah puts pelangganpenelitian gun sample hangman metope random sampling data rumpus uni validity reliability selanjutnyadata analysis denganmenggunakan tennis analysis regress linear ganda hail elite tuneup dimensikehandalan jamie but fisk day tanga pengaruh position significant puts hangman sedan dimension empty pengaruh puts hangman dimension paling pengaruh puts hangman jamie slain elite gun tennis analysis gap hail analysis gap tuneup dimension empty milk selfish nilgai position bear it jamie kehandalan dimension but fisk day tanga milk selfish nilgai negative tuneup ketidakpuasan hangman pick management hotel harp apart dingbat kualitas layman semi but fisk day tanga dingbat puts hangman hotel songgoriti making dingbat mass dating data bunch puts hangman kualitas layman serval
#
# --- Tokenisasi (Perhitungan Jumlah Kata) ---
# Frekuensi Kata (Indonesia): Counter({'puas': 10, 'langgan': 9, 'kualitas': 8, 'layan': 8, 'pengaruh': 6, 'hotel': 6, 'tingkat': 4, 'fisik': 4, 'daya': 4, 'tanggap': 4, 'jamin': 4, 'dimensi': 4, 'songgoriti': 3, 'teliti': 3, 'empati': 3, 'guna': 3, 'analisis': 3, 'tunjuk': 3, 'bukti': 3, 'air': 2, 'panas': 2, 'alam': 2, 'usaha': 2, 'pelangganpenelitian': 2, 'variabel': 2, 'kehandalan': 2, 'sedang': 2, 'teknik': 2, 'hasil': 2, 'positif': 2, 'gap': 2, 'milik': 2, 'selisih': 2, 'nilai': 2, 'aris': 1, 'rasyidityo': 1, 'munirhad': 1, 'suryo': 1, 'adhim': 1, 'bawah': 1, 'bimbing': 1, 'bapak': 1, 'fathor': 1, 'as': 1, 'yudi': 1, 'prasetya': 1, 'mada': 1, 'produk': 1, 'inti': 1, 'sebut': 1, 'buat': 1, 'para': 1, 'bidang': 1, 'terus': 1, 'unjung': 1, 'rasa': 1, 'laku': 1, 'beli': 1, 'ulang': 1, 'salah': 1, 'satu': 1, 'faktor': 1, 'tuju': 1, 'tahu': 1, 'independen': 1, 'dimensibukti': 1, 'dependen': 1, 'ialah': 1, 'sampel': 1, 'metode': 1, 'random': 1, 'sampling': 1, 'data': 1, 'kumpul': 1, 'uji': 1, 'validitas': 1, 'reliabilitas': 1, 'selanjutnyadata': 1, 'analis': 1, 'denganmenggunakan': 1, 'regresi': 1, 'linear': 1, 'ganda': 1, 'dimensikehandalan': 1, 'signifikan': 1, 'paling': 1, 'selain': 1, 'besar': 1, 'ikut': 1, 'negatif': 1, 'ketidakpuasan': 1, 'pihak': 1, 'manajemen': 1, 'harap': 1, 'dapat': 1, 'segi': 1, 'makin': 1, 'masa': 1, 'datang': 1, 'kata': 1, 'kunci': 1, 'servqual': 1})
# Frekuensi Kata (Inggris): Counter({'the': 22, 'of': 20, 'customer': 9, 'quality': 8, 'service': 8, 'satisfaction': 8, 'and': 7, 'in': 6, 'hotel': 5, 'is': 5, 'dimensions': 5, 'to': 4, 'that': 4, 'research': 4, 'reliability': 4, 'responsiveness': 4, 'assurance': 4, 'for': 3, 'songgoriti': 3, 'this': 3, 'tangibility': 3, 'empathy': 3, 'influence': 2, 'air': 2, 'panas': 2, 'alam': 2, 'while': 2, 'used': 2, 'by': 2, 'data': 2, 'results': 2, 'showed': 2, 'positive': 2, 'effect': 2, 'on': 2, 'gap': 2, 'analysis': 2, 'has': 2, 'value': 2, 'aris': 1, 'rasyidityo': 1, 'munirhad': 1, 'suryo': 1, 'adhim': 1, 'under': 1, 'guidance': 1, 'mr': 1, 'fathor': 1, 'as': 1, 'yudi': 1, 'prasetya': 1, 'mada': 1, 'core': 1, 'product': 1, 'who': 1, 'makes': 1, 'entrepreneurs': 1, 'hospitality': 1, 'keep': 1, 'increasing': 1, 'visitors': 1, 'are': 1, 'either': 1, 'satisfied': 1, 'or': 1, 'buy': 1, 'repeated': 1, 'one': 1, 'factor': 1, 'affects': 1, 'aim': 1, 'understand': 1, 'independent': 1, 'variables': 1, 'with': 1, 'dependent': 1, 'variable': 1, 'satisfactionthis': 1, 'sample': 1, 'customers': 1, 'random': 1, 'sampling': 1, 'method': 1, 'collected': 1, 'have': 1, 'been': 1, 'tested': 1, 'validity': 1, 'then': 1, 'were': 1, 'analyzed': 1, 'using': 1, 'multiple': 1, 'linear': 1, 'regression': 1, 'analysisthe': 1, 'tangibles': 1, 'significant': 1, 'had': 1, 'no': 1, 'most': 1, 'influential': 1, 'addition': 1, 'also': 1, 'use': 1, 'techniques': 1, 'dimension': 1, 'greatest': 1, 'difference': 1, 'followed': 1, 'but': 1, 'a': 1, 'negative': 1, 'suggests': 1, 'dissatisfied': 1, 'customerthe': 1, 'management': 1, 'expected': 1, 'improve': 1, 'terms': 1, 'increase': 1, 'level': 1, 'future': 1, 'kata': 1, 'kunci': 1, 'servqual': 1})
# -------------------------------------------
#
#
# --- Data #409 ---
# Prodi: Manajemen
# Penulis: Nuzul Qur’aini Risanah
# Judul: Analisis Pengaruh Ukuran Perusahaan, Risiko Bisnis, Profitabilitas, dan Struktur Aktiva Terhadap Struktur Modal Pada Perusahaan Farmasi Yang Terdaftar Di Bursa Efek Indonesia (BEI) Periode 2010-2014
# Pembimbing 1: Drs. Ec. Makhmud Zulkifli, M. Si
# Pembimbing 2: Drs. Bambang Sudarsono, MM
# Abstrak (Raw): Penelitian ini bertujuan untuk mengetahui dan menganalisis pengaruh ukuran perusahaan, risiko bisnis, profitabilitas, dan struktur aktiva terhadap struktur modal pada perusahaan farmasi yang terdaftar di Bursa Efek Indonesia (BEI) periode 2010-2014, baik secara simultan maupun parsial. Penelitian ini menggunakan pendekatan kuantitatif. Penelitian ini menggunakan data sekunder dengan sumber data yang berasal dari laporan keuangan perusahaan yang tercatat di Bursa Efek Indonesia (BEI) periode 2010-2014. Populasi penelitian sebanyak 9 perusahaan, dimana pengambilan sampel penelitian dengan menggunakan metode purposive sampling yaitu suatu metode pengambilan sampel dengan kriteria tertentu. Banyaknya sampel yang sesuai dengan kriteria adalah 8 perusahaan.
# Dari hasil penelitian menunjukkan bahwa secara simultan variabel ukuran perusahaan, risiko bisnis, profitabilitas dan struktur aktiva berpengaruh signifikan terhadap struktur modal dengan nilai uji F sebesar 0,000. Sedangkan secara parsial variabel yang berpengaruh secara signifikan terhadap struktur modal adalah ukuran perusahaan dan struktur aktiva dengan nilai uji t untuk ukuran perusahaan sebesar 0,001 dan struktur aktiva sebesar 0,000 dan yang tidak berpengaruh signifikan terhadap struktur modal adalah risiko bisnis dan profitabilitas dengan nilai uji t untuk risiko bisnis sebesar 0,876 dan profitabilitas sebesar 0,318 yang lebih besar dari taraf signifikan ? = 0,05. Besarnya koefisien determinasi (R2) sebesar 0,581 atau 58,1%, hasil ini menunjukkan variabel dependen dapat dijelaskan oleh variabel independen dan sisanya 41,9% dijelaskan oleh variabel lain yang tidak termasuk dalam penelitian ini.
#
# Kata Kunci : Struktur modal, Ukuran perusahaan, Risiko bisnis, Profitabilitas, dan Struktur aktiva.
# Abstrak (Clean): penelitian ini bertujuan untuk mengetahui dan menganalisis pengaruh ukuran perusahaan risiko bisnis profitabilitas dan struktur aktiva terhadap struktur modal pada perusahaan farmasi yang terdaftar di bursa efek indonesia bei periode baik secara simultan maupun parsial penelitian ini menggunakan pendekatan kuantitatif penelitian ini menggunakan data sekunder dengan sumber data yang berasal dari laporan keuangan perusahaan yang tercatat di bursa efek indonesia bei periode populasi penelitian sebanyak perusahaan dimana pengambilan sampel penelitian dengan menggunakan metode purposive sampling yaitu suatu metode pengambilan sampel dengan kriteria tertentu banyaknya sampel yang sesuai dengan kriteria adalah perusahaan dari hasil penelitian menunjukkan bahwa secara simultan variabel ukuran perusahaan risiko bisnis profitabilitas dan struktur aktiva berpengaruh signifikan terhadap struktur modal dengan nilai uji f sebesar sedangkan secara parsial variabel yang berpengaruh secara signifikan terhadap struktur modal adalah ukuran perusahaan dan struktur aktiva dengan nilai uji t untuk ukuran perusahaan sebesar dan struktur aktiva sebesar dan yang tidak berpengaruh signifikan terhadap struktur modal adalah risiko bisnis dan profitabilitas dengan nilai uji t untuk risiko bisnis sebesar dan profitabilitas sebesar yang lebih besar dari taraf signifikan besarnya koefisien determinasi r sebesar atau hasil ini menunjukkan variabel dependen dapat dijelaskan oleh variabel independen dan sisanya dijelaskan oleh variabel lain yang tidak termasuk dalam penelitian ini kata kunci struktur modal ukuran perusahaan risiko bisnis profitabilitas dan struktur aktiva
# Abstrak (Stopwords Removed): penelitian bertujuan mengetahui menganalisis pengaruh ukuran perusahaan risiko bisnis profitabilitas struktur aktiva struktur modal perusahaan farmasi terdaftar bursa efek indonesia bei periode baik secara simultan maupun parsial penelitian menggunakan pendekatan kuantitatif penelitian menggunakan data sekunder sumber data berasal laporan keuangan perusahaan tercatat bursa efek indonesia bei periode populasi penelitian sebanyak perusahaan dimana pengambilan sampel penelitian menggunakan metode purposive sampling metode pengambilan sampel kriteria tertentu banyaknya sampel sesuai kriteria perusahaan hasil penelitian menunjukkan secara simultan variabel ukuran perusahaan risiko bisnis profitabilitas struktur aktiva berpengaruh signifikan struktur modal nilai uji f sebesar sedangkan secara parsial variabel berpengaruh secara signifikan struktur modal ukuran perusahaan struktur aktiva nilai uji t ukuran perusahaan sebesar struktur aktiva sebesar berpengaruh signifikan struktur modal risiko bisnis profitabilitas nilai uji t risiko bisnis sebesar profitabilitas sebesar lebih besar taraf signifikan besarnya koefisien determinasi r sebesar hasil menunjukkan variabel dependen dapat dijelaskan variabel independen sisanya dijelaskan variabel lain termasuk penelitian kata kunci struktur modal ukuran perusahaan risiko bisnis profitabilitas struktur aktiva
# Abstrak (Stemmed): teliti tuju tahu analis pengaruh ukur usaha risiko bisnis profitabilitas struktur aktiva struktur modal usaha farmasi daftar bursa efek indonesia bei periode baik cara simultan maupun parsial teliti guna dekat kuantitatif teliti guna data sekunder sumber data asal lapor uang usaha catat bursa efek indonesia bei periode populasi teliti banyak usaha mana ambil sampel teliti guna metode purposive sampling metode ambil sampel kriteria tentu banyak sampel sesuai kriteria usaha hasil teliti tunjuk cara simultan variabel ukur usaha risiko bisnis profitabilitas struktur aktiva pengaruh signifikan struktur modal nilai uji f besar sedang cara parsial variabel pengaruh cara signifikan struktur modal ukur usaha struktur aktiva nilai uji t ukur usaha besar struktur aktiva besar pengaruh signifikan struktur modal risiko bisnis profitabilitas nilai uji t risiko bisnis besar profitabilitas besar lebih besar taraf signifikan besar koefisien determinasi r besar hasil tunjuk variabel dependen dapat jelas variabel independen sisa jelas variabel lain masuk teliti kata kunci struktur modal ukur usaha risiko bisnis profitabilitas struktur aktiva
# Abstrak (Corrected): elite juju tau analysis pengaruh ukr sara risk basis profitability structure akiva structure modal sara farms dafter bursa eek indonesia be period back cara simulate maun partial elite gun dead kuantitatif elite gun data sender number data anal labor hang sara carat bursa eek indonesia be period popular elite banyan sara mana ambit sample elite gun metope purposive sampling metope ambit sample criteria tent banyan sample sexual criteria sara hail elite tuneup cara simulate variable ukr sara risk basis profitability structure akiva pengaruh significant structure modal nilgai uni f bear sedan cara partial variable pengaruh cara significant structure modal ukr sara structure akiva nilgai uni t ukr sara bear structure akiva bear pengaruh significant structure modal risk basis profitability nilgai uni t risk basis bear profitability bear leash bear tara significant bear koefisien determines r bear hail tuneup variable dependent apart jells variable independent visa jells variable lain mask elite data bunch structure modal ukr sara risk basis profitability structure akiva
#
# --- Tokenisasi (Perhitungan Jumlah Kata) ---
# Frekuensi Kata (Indonesia): Counter({'struktur': 10, 'usaha': 9, 'besar': 8, 'teliti': 7, 'ukur': 5, 'risiko': 5, 'bisnis': 5, 'profitabilitas': 5, 'aktiva': 5, 'modal': 5, 'variabel': 5, 'pengaruh': 4, 'cara': 4, 'signifikan': 4, 'guna': 3, 'sampel': 3, 'nilai': 3, 'uji': 3, 'bursa': 2, 'efek': 2, 'indonesia': 2, 'bei': 2, 'periode': 2, 'simultan': 2, '
# Abstrak (Raw): Penelitian ini bertujuan untuk mengetahui dan menganalisis pengaruh rasio aktivitas, profitabilitas, dan tingkat suku bunga terhadap return saham pada perusahaan makanan dan minuman yang terdaftar di Bursa Efek Indonesia (BEI) tahun 2010-2014, baik secara parsial maupun simultan. Banyaknya sampel yang sesuai dengan kriteria adalah 10 perusahaan. Penelitian ini menggunakan pendekatan kuantitatif. Penelitian ini menggunakan data sekunder dengan sumber data yang berasal dari laporan keuangan perusahaan dari Bursa Efek Indonesia periode 2010-2014, teknik pengambilan sampel menggunakan purposive sampling yaitu suatu metode pengambilan sampel dengan kriteria tertentu. Analisis data menggunakan analisis regresi linier berganda dengan uji hipotesis, meliputi uji t (t test), dan uji F (F test).
# Dari hasil penelitian menunjukkan bahwa secara simultan berpengaruh signifikan terhadap return saham dengan nilai 001 dengan tingkat signifikan 0,05. Sedangkan secara parsial variabel yang berpengaruh secara signifikan terhadap return saham adalah ITO, ROA, dan Tingkat Suku Bunga dan yang tidak berpengaruh signifikan terhadap return saham adalah TATO dan ROE. Besarnya determinasi (R2) sebesar 0,287 atau 28,7%, hasil ini menunjukkan variabel dependen dapat dijelaskan oleh variabel independen dan sisanya 71,3% dijelaskan oleh variabel lain yang tidak termasuk dalam penelitian ini
#
# Kata Kunci : Rasio Aktivitas, Rasio Profitabilitas, Tingkat Suku Bunga, dan Return saham.
# Abstrak (Clean): penelitian ini bertujuan untuk mengetahui dan menganalisis pengaruh rasio aktivitas profitabilitas dan tingkat suku bunga terhadap return saham pada perusahaan makanan dan minuman yang terdaftar di bursa efek indonesia bei tahun baik secara parsial maupun simultan banyaknya sampel yang sesuai dengan kriteria adalah perusahaan penelitian ini menggunakan pendekatan kuantitatif penelitian ini menggunakan data sekunder dengan sumber data yang berasal dari laporan keuangan perusahaan dari bursa efek indonesia periode teknik pengambilan sampel menggunakan purposive sampling yaitu suatu metode pengambilan sampel dengan kriteria tertentu analisis data menggunakan analisis regresi linier berganda dengan uji hipotesis meliputi uji t t test dan uji f f test dari hasil penelitian menunjukkan bahwa secara simultan berpengaruh signifikan terhadap return saham dengan nilai dengan tingkat signifikan sedangkan secara parsial variabel yang berpengaruh secara signifikan terhadap return saham adalah ito roa dan tingkat suku bunga dan yang tidak berpengaruh signifikan terhadap return saham adalah tato dan roe besarnya determinasi r sebesar atau hasil ini menunjukkan variabel dependen dapat dijelaskan oleh variabel independen dan sisanya dijelaskan oleh variabel lain yang tidak termasuk dalam penelitian ini kata kunci rasio aktivitas rasio profitabilitas tingkat suku bunga dan return saham
# Abstrak (Stopwords Removed): penelitian bertujuan mengetahui menganalisis pengaruh rasio aktivitas profitabilitas tingkat suku bunga return saham perusahaan makanan minuman terdaftar bursa efek indonesia bei tahun baik secara parsial maupun simultan banyaknya sampel sesuai kriteria perusahaan penelitian menggunakan pendekatan kuantitatif penelitian menggunakan data sekunder sumber data berasal laporan keuangan perusahaan bursa efek indonesia periode teknik pengambilan sampel menggunakan purposive sampling metode pengambilan sampel kriteria tertentu analisis data menggunakan analisis regresi linier berganda uji hipotesis meliputi uji t t test uji f f test hasil penelitian menunjukkan secara simultan berpengaruh signifikan return saham nilai tingkat signifikan sedangkan secara parsial variabel berpengaruh secara signifikan return saham ito roa tingkat suku bunga berpengaruh signifikan return saham tato roe besarnya determinasi r sebesar hasil menunjukkan variabel dependen dapat dijelaskan variabel independen sisanya dijelaskan variabel lain termasuk penelitian kata kunci rasio aktivitas rasio profitabilitas tingkat suku bunga return saham
# Abstrak (Stemmed): teliti tuju tahu analis pengaruh rasio aktivitas profitabilitas tingkat suku bunga return saham usaha makan minum daftar bursa efek indonesia bei tahun baik cara parsial maupun simultan banyak sampel sesuai kriteria usaha teliti guna dekat kuantitatif teliti guna data sekunder sumber data asal lapor uang usaha bursa efek indonesia periode teknik ambil sampel guna purposive sampling metode ambil sampel kriteria tentu analisis data guna analisis regresi linier ganda uji hipotesis liput uji t t test uji f f test hasil teliti tunjuk cara simultan pengaruh signifikan return saham nilai tingkat signifikan sedang cara parsial variabel pengaruh cara signifikan return saham ito roa tingkat suku bunga pengaruh signifikan return saham tato roe besar determinasi r besar hasil tunjuk variabel dependen dapat jelas variabel independen sisa jelas variabel lain masuk teliti kata kunci rasio aktivitas rasio profitabilitas tingkat suku bunga return saham
# Abstrak (Corrected): elite juju tau analysis pengaruh radio aktivitas profitability dingbat sulu bung return sham sara mayan minus dafter bursa eek indonesia be thun back cara partial maun simulate banyan sample sexual criteria sara elite gun dead kuantitatif elite gun data sender number data anal labor hang sara bursa eek indonesia period tennis ambit sample gun purposive sampling metope ambit sample criteria tent analysis data gun analysis regress linger ganda uni hypothesis lieut uni t t test uni f f test hail elite tuneup cara simulate pengaruh significant return sham nilgai dingbat significant sedan cara partial variable pengaruh cara significant return sham ito road dingbat sulu bung pengaruh significant return sham taco roe bear determines r bear hail tuneup variable dependent apart jells variable independent visa jells variable lain mask elite data bunch radio aktivitas radio profitability dingbat sulu bung return sham
#
# --- Tokenisasi (Perhitungan Jumlah Kata) ---
# Frekuensi Kata (Indonesia): Counter({'teliti': 5, 'return': 5, 'saham': 5, 'pengaruh': 4, 'tingkat': 4, 'cara': 4, 'guna': 4, 'signifikan': 4, 'variabel': 4, 'rasio': 3, 'suku': 3, 'bunga': 3, 'usaha': 3, 'sampel': 3, 'data': 3, 'uji': 3, 'aktivitas': 2, 'profitabilitas': 2, 'bursa': 2, 'efek': 2, 'indonesia': 2, 'parsial': 2, 'simultan': 2, 'kriteria': 2, 'ambil': 2, 'analisis': 2, 't': 2, 'test': 2, 'f': 2, 'hasil': 2, 'tunjuk': 2, 'besar': 2, 'jelas': 2, 'tuju': 1, 'tahu': 1, 'analis': 1, 'makan': 1, 'minum': 1, 'daftar': 1, 'bei': 1, 'tahun': 1, 'baik': 1, 'maupun': 1, 'banyak': 1, 'sesuai': 1, 'dekat': 1, 'kuantitatif': 1, 'sekunder': 1, 'sumber': 1, 'asal': 1, 'lapor': 1, 'uang': 1, 'periode': 1, 'teknik': 1, 'purposive': 1, 'sampling': 1, 'metode': 1, 'tentu': 1, 'regresi': 1, 'linier': 1, 'ganda': 1, 'hipotesis': 1, 'liput': 1, 'nilai': 1, 'sedang': 1, 'ito': 1, 'roa': 1, 'tato': 1, 'roe': 1, 'determinasi': 1, 'r': 1, 'dependen': 1, 'dapat': 1, 'independen': 1, 'sisa': 1, 'lain': 1, 'masuk': 1, 'kata': 1, 'kunci': 1})
# Frekuensi Kata (Inggris): Counter({'the': 15, 'and': 9, 'of': 8, 'stock': 7, 'that': 7, 'this': 5, 'study': 5, 'on': 5, 'return': 5, 'with': 5, 'variables': 5, 'effect': 4, 'ratio': 4, 'in': 4, 'are': 4, 'uses': 4, 'significant': 4, 'interest': 3, 'rate': 3, 'companies': 3, 'data': 3, 'sampling': 3, 'a': 3, 'test': 3, 'have': 3, 'is': 2, 'activity': 2, 'profitability': 2, 'indonesian': 2, 'exchange': 2, 'partially': 2, 'or': 2, 'simultaneously': 2, 'criteria': 2, 'from': 2, 'analysis': 2, 'do': 2, 'not': 2, 'explained': 2, 'by': 2, 'aimed': 1, 'to': 1, 'determine': 1, 'analyze': 1, 'food': 1, 'beverage': 1, 'listed': 1, 'bei': 1, 'either': 1, 'samples': 1, 'meet': 1, 'quantitative': 1, 'approach': 1, 'secondary': 1, 'source': 1, 'derived': 1, 'financial': 1, 'statements': 1, 'technique': 1, 'purposive': 1, 'method': 1, 'certain': 1, 'multiple': 1, 'linear': 1, 'regression': 1, 'hypothesis': 1, 'including': 1, 't': 1, 'f': 1, 'results': 1, 'show': 1, 'value': 1, 'level': 1, 'whereas': 1, 'ito': 1, 'roa': 1, 'tato': 1, 'roe': 1, 'amount': 1, 'determination': 1, 'r': 1, 'shows': 1, 'dependent': 1, 'can': 1, 'be': 1, 'independent': 1, 'remaining': 1, 'other': 1, 'included': 1, 'keywords': 1})
# -------------------------------------------
#
#
# --- Data #411 ---
# Prodi: Manajemen
# Penulis: Wulan Dwi Ifalil Y
# Judul: Pengaruh Pelatihan Dan Penilaian Prestasi Kerja Terhadap Promosi Jabatan karyawan Kantor Cabang BANK BRI Nganjuk
# Pembimbing 1: Dr. Muhammad Alkirom Wildan,SE, MSi
# Pembimbing 2: Dra. Hj. S. Anugrahini Irawati, MM
# Abstrak (Raw): Pelatihan dan Penilaian Prestasi Kerja merupakan salah satu faktor penting yang dapat mempengaruhi Promosi Jabatan. Dalam melaksanakan pekerjaan, karyawan memerlukan pelatihan agar bisa melaksanakan tugas sesuai bidangnya, penilaian prestasi kerja rendah juga berpengaruh terhadap promosi jabatan.   Penelitian ini bertujuan untuk menguji pengaruh Pelatihan (X1), Penilaian Prestasi Kerja(X2) terhadap Promosi Jabatan karyawan Kantor Cabang BANK BRI Nganjuk.  Penelitian ini menggunakan metode kuantitatif dimana populasinya adalah seluruh karyawan Kantor Cabang BANK BRI Nganjuk yang berjumlah 116 responden. Jumlah sampel yang digunakan dalam penelitian ini sebanyak 54 karyawan, yang diambil menggunakan metode wawancara, kepustakaan dan kuesioner. Analisis data menggunakan analisis regresi linear berganda dengan bantuan program SPSS. Berdasarkan hasil analisis regresi linier berganda diperoleh hasil bahwa secara parsial variabel pelatihan, dan penilaian prestasi kerja berpengaruh positif d
 'parsial': 2, 'besar': 2, 'salah': 1, 'satu': 1, 'faktor': 1, 'perlu': 1, 'tugas': 1, 'sesuai': 1, 'bidang': 1, 'rendah': 1, 'tuju': 1, 'uji': 1, 'x': 1, 'kerjax': 1, 'kuantitatif': 1, 'mana': 1, 'populasi': 1, 'seluruh': 1, 'sampel': 1, 'banyak': 1, 'ambil': 1, 'wawancara': 1, 'pustaka': 1, 'kuesioner': 1, 'data': 1, 'linear': 1, 'bantu': 1, 'program': 1, 'spss': 1, 'dasar': 1, 'linier': 1, 'oleh': 1, 'positif': 1, 'signifikan': 1, 'simultan': 1, 'adjusted': 1, 'r': 1, 'square': 1, 'f': 1, 'hitung': 1, 'arti': 1, 'nyata': 1, 'semua': 1, 'bebas': 1, 'sebut': 1, 'anggap': 1, 'tingkat': 1, 'tunjuk': 1, 'koefisien': 1, 'punya': 1, 'dominan': 1, 'kata': 1, 'kunci': 1})
# Frekuensi Kata (Inggris): Counter({'the': 19, 'of': 11, 'that': 9, 'training': 7, 'performance': 7, 'appraisal': 7, 'promotion': 7, 'is': 7, 'and': 6, 'on': 6, 'effect': 4, 'in': 4, 'employees': 4, 'to': 4, 'bri': 4, 'bank': 4, 'branch': 4, 'nganjuk': 4, 'have': 3, 'an': 3, 'study': 3, 'analysis': 3, 'with': 3, 'value': 3, 'b': 3, 'x': 2, 'this': 2, 'uses': 2, 'all': 2, 'multiple': 2, 'linear': 2, 'regression': 2, 'partially': 2, 'are': 1, 'factors': 1, 'carrying': 1, 'out': 1, 'works': 1, 'need': 1, 'a': 1, 'order': 1, 'excute': 1, 'task': 1, 'more': 1, 'also': 1, 'effecting': 1, 'promotionthis': 1, 'has': 1, 'objective': 1, 'examine': 1, 'y': 1, 'quantitatieve': 1, 'method': 1, 'which': 1, 'population': 1, 'employess': 1, 'amounted': 1, 'respondents': 1, 'total': 1, 'sample': 1, 'used': 1, 'selected': 1, 'by': 1, 'using': 1, 'interview': 1, 'literature': 1, 'uestionnaire': 1, 'methods': 1, 'data': 1, 'spss': 1, 'program': 1, 'based': 1, 'result': 1, 'it': 1, 'obtained': 1, 'significant': 1, 'positive': 1, 'ofemployees': 1, 'variable': 1, 'simultaneously': 1, 'variables': 1, 'adjusted': 1, 'r': 1, 'square': 1, 'fcount': 1, 'means': 1, 'respondent': 1, 'said': 1, 'independent': 1, 'variabel': 1, 'consident': 1, 'important': 1, 'increase': 1, 'its': 1, 'showed': 1, 'performanceappraisal': 1, 'most': 1, 'dominant': 1, 'key': 1, 'words': 1})
# -------------------------------------------
#
#
# --- Data #412 ---
# Prodi: Manajemen
# Penulis: FATHOR ROSI
# Judul: Pengaruh Hargadan Kualitas ProdukTerhadap Keputusan Pembelian Sarung Samarinda (Studi Pada Pelanggan Toko Sarung Abu Ulfa di Kabupaten Sampang)
# Pembimbing 1: Fathor AS, S.E., M.M
# ...
# -------------------------------------------
#
#
# --- Data #576 ---
# Prodi: Manajemen
# Penulis: Ermawati
# Judul: ANALISIS PREDIKSI TINGKAT KESEHATAN DENGAN   MENGGUNAKAN METODE ALTMAN Z-SCORE DAN METODE SPRINGATE PADA PERUSAHAAN OTOMOTIF YANG TERDAFTAR DI BURSA EFEK INDONESIA PERIODE 2013-2016
# Pembimbing 1: Dr.Drs.Ec.Chairul Anam,M.Kes
# Pembimbing 2: Purnamawati,SE.,MSI
# Abstrak (Raw): ABSTRAK
#  Penelitian ini bertujuan untuk memprediksi tingkat kesehatan dengan menggunakan metode Altman Z-score dan metode Springate pada Perusahaan Otomotif berdasarkan interprestasi metode Altman Z-score dan metode Springate apakah perusahaan otomotif masuk dalam kategori sehat, grey area (rawan), atau masuk dalam kategori bangkrut. Jenis penelitian ini adalah penelitian deskriptif dengan sample 8 perusahaan otomotif yang terdaftar di Bursa Efek Indonesia dari periode 2013-2016. Dari hasil pengolahan dan analisis data keuangan tahun 2013-2016 diperoleh hasil dengan menggunakan metode Altman Z-score ditemukan tahun 2013 ada empat perusahaan sehat,dua perusahaan grey area,dua perusahaan bangkrut, ditahun 2014 lima perusahaan sehat,tiga perusahaan, ditahun 2015 satu perusahaan sehat,dua perusahaan grey area,lima perusahaan bangkrut, ditahun 2016 tiga perusahaan sehat,satu perusahaan grey area,empat perusahaan bangkrut. Sedangkan model Springate ditemukan tahun 2013 ada lima perusahaan, empat perusahaan ditahun 2014, satu perusahaan ditahun 2015, dan satu perusahaan ditahun 2016 berada dalam posisi sehat.
#
# Kata Kunci : Altman Z-score dan Springate.
# Abstrak (Clean): abstrak penelitian ini bertujuan untuk memprediksi tingkat kesehatan dengan menggunakan metode altman zscore dan metode springate pada perusahaan otomotif berdasarkan interprestasi metode altman zscore dan metode springate apakah perusahaan otomotif masuk dalam kategori sehat grey area rawan atau masuk dalam kategori bangkrut jenis penelitian ini adalah penelitian deskriptif dengan sample perusahaan otomotif yang terdaftar di bursa efek indonesia dari periode dari hasil pengolahan dan analisis data keuangan tahun diperoleh hasil dengan menggunakan metode altman zscore ditemukan tahun ada empat perusahaan sehatdua perusahaan grey areadua perusahaan bangkrut ditahun lima perusahaan sehattiga perusahaan ditahun satu perusahaan sehatdua perusahaan grey arealima perusahaan bangkrut ditahun tiga perusahaan sehatsatu perusahaan grey areaempat perusahaan bangkrut sedangkan model springate ditemukan tahun ada lima perusahaan empat perusahaan ditahun satu perusahaan ditahun dan satu perusahaan ditahun berada dalam posisi sehat kata kunci altman zscore dan springate
# Abstrak (Stopwords Removed): abstrak penelitian bertujuan memprediksi tingkat kesehatan menggunakan metode altman zscore metode springate perusahaan otomotif berdasarkan interprestasi metode altman zscore metode springate apakah perusahaan otomotif masuk kategori sehat grey area rawan masuk kategori bangkrut jenis penelitian penelitian deskriptif sample perusahaan otomotif terdaftar bursa efek indonesia periode hasil pengolahan analisis data keuangan tahun diperoleh hasil menggunakan metode altman zscore ditemukan tahun ada empat perusahaan sehatdua perusahaan grey areadua perusahaan bangkrut ditahun lima perusahaan sehattiga perusahaan ditahun satu perusahaan sehatdua perusahaan grey arealima perusahaan bangkrut ditahun tiga perusahaan sehatsatu perusahaan grey areaempat perusahaan bangkrut sedangkan model springate ditemukan tahun ada lima perusahaan empat perusahaan ditahun satu perusahaan ditahun satu perusahaan ditahun berada posisi sehat kata kunci altman zscore springate
 2, 'from': 2, 'by': 2, 'found': 2, 'there': 2, 'three': 2, 'abstract': 1, 'study': 1, 'aims': 1, 'to': 1, 'predict': 1, 'level': 1, 'health': 1, 'based': 1, 'on': 1, 'interpretation': 1, 'whether': 1, 'vulnerable': 1, 'or': 1, 'entered': 1, 'into': 1, 'bankruptcy': 1, 'type': 1, 'descriptive': 1, 'with': 1, 'sample': 1, 'listed': 1, 'bursa': 1, 'efek': 1, 'indonesia': 1, 'period': 1, 'results': 1, 'processing': 1, 'analysis': 1, 'financial': 1, 'data': 1, 'obtained': 1, 'go': 1, 'went': 1, 'while': 1, 'model': 1, 'a': 1, 'position': 1, 'keywords': 1})
# -------------------------------------------
#
#
# --- Data #577 ---
# Prodi: Manajemen
# Penulis: Adista Dwi Lestari
# Judul: Pengaruh Store Atmosphere terhadap Keputusan Pembelian di Ole Olang Resto Bangkalan
# Pembimbing 1: Dr. Ir. Nurita Andriani, MM
# Pembimbing 2: Yustina Chrismardani, S.Si., MM
# Abstrak (Raw): ABSTRAK
#  Adista Dwi Lestari (2017), Pengaruh Store Atmosphere terhadap Keputusan Pembelian di Ole Olang Resto Bangkalan. Dibawah bimbingan Dr. Ir. Nurita Andriani, MM dan Yustina Chrismardani, S.Si., MM.
#  Tujuan penelitian ini adalah untuk mengetahui tingkat keputusan konsumen atas Store Atmosphere yang dilaksanakan di Ole Olang Resto Bangkalan, secara parsial terhadap keputusan pembelian.
#  Penelitian ini dilakukan secara kuantitatif dengan metode penyebaran kuesioner di Ole Olang Resto Bangkalan. Teknik pengambilan sampel menggunakan accidental sampling dengan analisis regresi linier berganda dan data diolah menggunakan software computer SPSS 16.  Hasil penelitian  menunjukkan bahwa secara parsial, exterior berpengaruh secara signifikan terhadap keputusan pembelian, general Interior berpengaruh secara signifikan terhadap keputusan pembelian, Store Layout berpengaruh secara signifikan terhadap keputusan pembelian, dan variabel Interior Display berpengaruh secara signifikan terhadap keputusan pembelian.  Hasil menunjukkan bahwa sebesar 68,6% keputusan pembelian dipengaruhi oleh faktor Store Atmosphere, sedangkan sisanya sebesar 31,4% dipengaruhi oleh variabel lain. Variabel yang paling besar berpengaruh terhadap keputusan pembelian adalah interior display.
#
# Kata Kunci : Store Atmosphere, Exterior, General Interior, Store Layout, dan Interior Display
# Abstrak (Clean): abstrak adista dwi lestari pengaruh store atmosphere terhadap keputusan pembelian di ole olang resto bangkalan dibawah bimbingan dr ir nurita andriani mm dan yustina chrismardani ssi mm tujuan penelitian ini adalah untuk mengetahui tingkat keputusan konsumen atas store atmosphere yang dilaksanakan di ole olang resto bangkalan secara parsial terhadap keputusan pembelian penelitian ini dilakukan secara kuantitatif dengan metode penyebaran kuesioner di ole olang resto bangkalan teknik pengambilan sampel menggunakan accidental sampling dengan analisis regresi linier berganda dan data diolah menggunakan software computer spss hasil penelitian menunjukkan bahwa secara parsial exterior berpengaruh secara signifikan terhadap keputusan pembelian general interior berpengaruh secara signifikan terhadap keputusan pembelian store layout berpengaruh secara signifikan terhadap keputusan pembelian dan variabel interior display berpengaruh secara signifikan terhadap keputusan pembelian hasil menunjukkan bahwa sebesar keputusan pembelian dipengaruhi oleh faktor store atmosphere sedangkan sisanya sebesar dipengaruhi oleh variabel lain variabel yang paling besar berpengaruh terhadap keputusan pembelian adalah interior display kata kunci store atmosphere exterior general interior store layout dan interior display
# Frekuensi Kata (Indonesia): Counter({'putus': 9, 'pengaruh': 8, 'beli': 8, 'cara': 7, 'store': 6, 'interior': 5, 'atmosphere': 4, 'signifikan': 4, 'ole': 3, 'olang': 3, 'resto': 3, 'bangkal': 3, 'teliti': 3, 'variabel': 3, 'display': 3, 'besar': 3, 'mm': 2, 'parsial': 2, 'guna': 2, 'hasil': 2, 'tunjuk': 2, 'exterior': 2, 'general': 2, 'layout': 2, 'abstrak': 1, 'adista': 1, 'dwi': 1, 'lestari': 1, 'bawah': 1, 'bimbing': 1, 'dr': 1, 'ir': 1, 'nurita': 1, 'andriani': 1, 'yustina': 1, 'chrismardani': 1, 'ssi': 1, 'tuju': 1, 'tahu': 1, 'tingkat': 1, 'konsumen': 1, 'atas': 1, 'laksana': 1, 'laku': 1, 'kuantitatif': 1, 'metode': 1, 'sebar': 1, 'kuesioner': 1, 'teknik': 1, 'ambil': 1, 'sampel': 1, 'accidental': 1, 'sampling': 1, 'analisis': 1, 'regresi': 1, 'linier': 1, 'ganda': 1, 'data': 1, 'olah': 1, 'software': 1, 'computer': 1, 'spss': 1, 'faktor': 1, 'sedang': 1, 'sisa': 1, 'lain': 1, 'paling': 1, 'kata': 1, 'kunci': 1})
# Frekuensi Kata (Inggris): Counter({'the': 10, 'purchase': 8, 'decision': 7, 'store': 6, 'influence': 5, 'of': 5, 'on': 5, 'is': 5, 'interior': 5, 'atmosphere': 4, 'and': 4, 'study': 4, 'at': 3, 'ole': 3, 'olang': 3, 'resto': 3, 'bangkal': 3, 'this': 3, 'that': 3, 'has': 3, 'significant': 3, 'display': 3, 'mm': 2, 'to': 2, 'decisions': 2, 'partially': 2, 'with': 2, 'sampling': 2, 'results': 2, 'show': 2, 'exterior': 2, 'general': 2, 'layout': 2, 'variables': 2, 'influenced': 2, 'by': 2, 'abstract': 1, 'adista': 1, 'dwi': 1, 'lestari': 1, 'advisors': 1, 'dr': 1, 'ir': 1, 'nurita': 1, 'andriani': 1, 'yustina': 1, 'chrismardani': 1, 'ssi': 1, 'aims': 1, 'determine': 1, 'level': 1, 'consumer': 1, 'was': 1, 'conducted': 1, 'designed': 1, 'as': 1, 'a': 1, 'quantitative': 1, 'method': 1, 'distributing': 1, 'questionnaires': 1, 'technique': 1, 'used': 1, 'in': 1, 'accidental': 1, 'multiple': 1, 'linear': 1, 'regression': 1, 'analysis': 1, 'data': 1, 'are': 1, 'processed': 1, 'using': 1, 'computer': 1, 'software': 1, 'spss': 1, 'significantly': 1, 'while': 1, 'rest': 1, 'other': 1, 'largest': 1, 'variable': 1, 'affecting': 1, 'keywords': 1})
# -------------------------------------------

# %% [markdown]
# ## Page & Link Keluar PTA

# %%
import urllib3
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import pandas as pd

# matikan warning SSL insecure
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

def scrape_all_links(base_url, max_pages=50):
    visited = set()
    results = []

    def scrape_page(url):
        try:
            response = requests.get(url, verify=False, timeout=10)
            soup = BeautifulSoup(response.text, 'html.parser')

            # ambil semua link keluar
            for a in soup.find_all('a', href=True):
                href = a['href'].strip()
                if not href or href == "#":
                    continue
                full_link = urljoin(url, href)
                results.append({
                    "Page": url,
                    "Link Keluar": full_link
                })

            # cari link internal untuk dilanjutkan
            for a in soup.find_all('a', href=True):
                href = a['href'].strip()
                if not href or href == "#":
                    continue
                full_link = urljoin(url, href)
                # hanya ambil link internal (masih di domain utama)
                if full_link.startswith(base_url) and full_link not in visited:
                    visited.add(full_link)
                    if len(visited) < max_pages:
                        scrape_page(full_link)

        except Exception as e:
            print(f"⚠️ Gagal akses {url}: {e}")

    # mulai dari base_url
    visited.add(base_url)
    scrape_page(base_url)

    # rapikan dataframe
    df = pd.DataFrame(results).reset_index(drop=True)
    df.index += 1
    df.insert(0, "No", df.index)
    return df

# contoh penggunaan
url = "https://manajemen.trunojoyo.ac.id/"
df_links = scrape_all_links(url, max_pages=30)  # max_pages = batas biar ga infinite loop

df_links
# df_links.to_csv("semua_link.csv", index=False, encoding="utf-8-sig")
# Out:
#         No                                               Page  \
# 1        1                 https://manajemen.trunojoyo.ac.id/
# 2        2                 https://manajemen.trunojoyo.ac.id/
# 3        3                 https://manajemen.trunojoyo.ac.id/
# 4        4                 https://manajemen.trunojoyo.ac.id/
# 5        5                 https://manajemen.trunojoyo.ac.id/
# ...    ...                                                ...
# 2469  2469  https://manajemen.trunojoyo.ac.id/kalender-aka...
# 2470  2470  https://manajemen.trunojoyo.ac.id/kalender-aka...
# 2471  2471  https://manajemen.trunojoyo.ac.id/kalender-aka...
# 2472  2472  https://manajemen.trunojoyo.ac.id/kalender-aka...
# 2473  2473  https://manajemen.trunojoyo.ac.id/kalender-aka...
#
#                                             Link Keluar
# 1            https://manajemen.trunojoyo.ac.id/#content
# 2                                      tel:082330605254
# 3                      mailto:manajemen@trunojoyo.ac.id
# 4                    https://manajemen.trunojoyo.ac.id/
# 5                    https://manajemen.trunojoyo.ac.id/
# ...                                                 ...
# 2469  https://manajemen.trunojoyo.ac.id/visit-compan...
# 2470  https://manajemen.trunojoyo.ac.id/internationa...
# 2471                             https://wordpress.org/
# 2472                             https://wenthemes.com/
# 2473  https://manajemen.trunojoyo.ac.id/kalender-aka...
#
# [2473 rows x 3 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df_links['No'].plot(kind='hist', bins=20, title='No')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['No']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'No'}, axis=1)
#               .sort_values('No', ascending=True))
#   xs = counted['No']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = df_links.sort_values('No', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('No')
# _ = plt.ylabel('count()')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df_links['No'].plot(kind='line', figsize=(8, 4), title='No')
# plt.gca().spines[['top', 'right']].set_visible(False)
