# %% [markdown]
# # CRAWLING PTA MANAJEMEN & Berita

# %%
# !pip install builtwith
# !pip install nltk
# !pip install Sastrawi
# !pip install pyspellchecker
# Out:
# Collecting builtwith
#   Downloading builtwith-1.3.4.tar.gz (34 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: six in c:\users\raihan fadillah\appdata\local\programs\python\python313\lib\site-packages (from builtwith) (1.17.0)
# Building wheels for collected packages: builtwith
#   Building wheel for builtwith (pyproject.toml): started
#   Building wheel for builtwith (pyproject.toml): finished with status 'done'
#   Created wheel for builtwith: filename=builtwith-1.3.4-py3-none-any.whl size=36133 sha256=ca02abe2427ec9929d20aea7005a5c9ce1ebaf626727aeb8f726ea92bc3d390f
#   Stored in directory: c:\users\raihan fadillah\appdata\local\pip\cache\wheels\ac\22\54\51e70a84f60595e3a31a30ecdde2438d1f76007d17ab8c9270
# Successfully built builtwith
# Installing collected packages: builtwith
# Successfully installed builtwith-1.3.4
# Collecting nltk
#   Downloading nltk-3.9.1-py3-none-any.whl.metadata (2.9 kB)
# Collecting click (from nltk)
#   Downloading click-8.2.1-py3-none-any.whl.metadata (2.5 kB)
# Collecting joblib (from nltk)
#   Downloading joblib-1.5.2-py3-none-any.whl.metadata (5.6 kB)
# Collecting regex>=2021.8.3 (from nltk)
#   Downloading regex-2025.9.1-cp313-cp313-win_amd64.whl.metadata (41 kB)
# Collecting tqdm (from nltk)
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: colorama in c:\users\raihan fadillah\appdata\local\programs\python\python313\lib\site-packages (from click->nltk) (0.4.6)
# Downloading nltk-3.9.1-py3-none-any.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.5 MB ? eta -:--:--
#    ------------- -------------------------- 0.5/1.5 MB 2.4 MB/s eta 0:00:01
#    --------------------------- ------------ 1.0/1.5 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------- 1.5/1.5 MB 1.9 MB/s  0:00:00
# Downloading regex-2025.9.1-cp313-cp313-win_amd64.whl (275 kB)
# Downloading click-8.2.1-py3-none-any.whl (102 kB)
# Downloading joblib-1.5.2-py3-none-any.whl (308 kB)
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
# Installing collected packages: tqdm, regex, joblib, click, nltk
#
#    ---------------------------------------- 0/5 [tqdm]
#    ---------------------------------------- 0/5 [tqdm]
#    ---------------------------------------- 0/5 [tqdm]
#    -------- ------------------------------- 1/5 [regex]
#    ---------------- ----------------------- 2/5 [joblib]
#    ---------------- ----------------------- 2/5 [joblib]
#    ---------------- ----------------------- 2/5 [joblib]
#    ---------------- ----------------------- 2/5 [joblib]
#    ---------------- ----------------------- 2/5 [joblib]
#    ---------------- ----------------------- 2/5 [joblib]
#    ---------------- ----------------------- 2/5 [joblib]
#    ---------------- ----------------------- 2/5 [joblib]
#    ---------------- ----------------------- 2/5 [joblib]
#    ------------------------ --------------- 3/5 [click]
#    ------------------------ --------------- 3/5 [click]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    ---------------------------------------- 5/5 [nltk]
#
# Successfully installed click-8.2.1 joblib-1.5.2 nltk-3.9.1 regex-2025.9.1 tqdm-4.67.1
# Collecting Sastrawi
#   Downloading Sastrawi-1.0.1-py2.py3-none-any.whl.metadata (909 bytes)
# Downloading Sastrawi-1.0.1-py2.py3-none-any.whl (209 kB)
# Installing collected packages: Sastrawi
# Successfully installed Sastrawi-1.0.1
# Collecting pyspellchecker
#   Downloading pyspellchecker-0.8.3-py3-none-any.whl.metadata (9.5 kB)
# Downloading pyspellchecker-0.8.3-py3-none-any.whl (7.2 MB)
#    ---------------------------------------- 0.0/7.2 MB ? eta -:--:--
#    - -------------------------------------- 0.3/7.2 MB ? eta -:--:--
#    ---- ----------------------------------- 0.8/7.2 MB 2.8 MB/s eta 0:00:03
#    ------- -------------------------------- 1.3/7.2 MB 2.4 MB/s eta 0:00:03
#    ---------- ----------------------------- 1.8/7.2 MB 2.4 MB/s eta 0:00:03
#    ----------- ---------------------------- 2.1/7.2 MB 2.4 MB/s eta 0:00:03
#    -------------- ------------------------- 2.6/7.2 MB 2.4 MB/s eta 0:00:02
#    ----------------- ---------------------- 3.1/7.2 MB 2.3 MB/s eta 0:00:02
#    ------------------ --------------------- 3.4/7.2 MB 2.2 MB/s eta 0:00:02
#    --------------------- ------------------ 3.9/7.2 MB 2.2 MB/s eta 0:00:02
#    ----------------------- ---------------- 4.2/7.2 MB 2.2 MB/s eta 0:00:02
#    -------------------------- ------------- 4.7/7.2 MB 2.2 MB/s eta 0:00:02
#    ---------------------------- ----------- 5.2/7.2 MB 2.1 MB/s eta 0:00:01
#    ------------------------------ --------- 5.5/7.2 MB 2.1 MB/s eta 0:00:01
#    ------------------------------- -------- 5.8/7.2 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 6.3/7.2 MB 2.1 MB/s eta 0:00:01
#    ------------------------------------ --- 6.6/7.2 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------------- 7.2/7.2 MB 2.1 MB/s  0:00:03
# Installing collected packages: pyspellchecker
# Successfully installed pyspellchecker-0.8.3

# %% [markdown]
# ## 1. Crawling PTA

# %%
import builtwith

# Analisis teknologi yang digunakan
res = builtwith.parse('https://pta.trunojoyo.ac.id')
print(res)
# Out:
# {'web-servers': ['Nginx'], 'javascript-frameworks': ['jQuery', 'jQuery UI']}

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import sys

# --- Fungsi Bantu Scraping ---
def get_text_or_na(soup, selectors):
    for selector in selectors:
        element = soup.select_one(selector)
        if element:
            text = element.get_text(strip=True)
            if text:
                return text.strip()
    return 'N/A'

def get_data_from_span(soup, text_contains):
    span = soup.select_one(f'span:-soup-contains("{text_contains}")')
    if span:
        text = span.get_text(strip=True)
        if ':' in text:
            return text.split(':', 1)[1].strip()
    return 'N/A'

def get_abstract_robust(soup, keywords):
    for tag_b in soup.find_all('b'):
        tag_text = tag_b.get_text(strip=True)
        if any(keyword.lower() in tag_text.lower() for keyword in keywords):
            parent_div = tag_b.find_parent('div')
            if parent_div:
                next_div_sibling = parent_div.find_next_sibling('div')
                if next_div_sibling:
                    p_tag = next_div_sibling.find('p', align="justify")
                    if p_tag:
                        return p_tag.get_text(strip=True)
    return 'N/A'

def get_total_pages(soup):
    try:
        pagination = soup.select_one('ol.pagination')
        if pagination:
            last_page_li = pagination.select('li')[-1]
            last_page_link = last_page_li.select_one('a')
            if last_page_link and 'href' in last_page_link.attrs:
                return int(last_page_link['href'].split('/')[-1])
    except:
        pass
    return 1

# --- Fungsi Scraping ---
def scrape_manajemen_raw():
    prodi_data = [{'name': 'Manajemen', 'url': 'https://pta.trunojoyo.ac.id/c_search/byprod/7'}]
    all_data = {"penulis": [], "judul": [], "pembimbing_pertama": [], "pembimbing_kedua": [],
                "abstrak_indonesia": [], "abstrak_inggris": [], "prodi": []}

    total_data_count = 0
    print("--- MULAI SCRAPING (RAW DATA) ---")

    for prodi in prodi_data:
        first_page_url = prodi['url']
        try:
            r = requests.get(first_page_url)
            r.raise_for_status()
            soup = BeautifulSoup(r.content, "html.parser")
            total_pages = get_total_pages(soup)
            print(f"Ditemukan {total_pages} halaman untuk {prodi['name']}")
        except:
            total_pages = 1

        for i in range(1, total_pages + 1):
            url = f"{prodi['url']}/{i}"
            try:
                r = requests.get(url)
                r.raise_for_status()
                soup = BeautifulSoup(r.content, "html.parser")
                jurnals = soup.select('li[data-cat="#luxury"]')

                if not jurnals:
                    break

                for jurnal in jurnals:
                    jurnal_url = jurnal.select_one('a.gray.button')['href']
                    try:
                        response = requests.get(jurnal_url)
                        response.raise_for_status()
                        soup1 = BeautifulSoup(response.content, "html.parser")
                        isi = soup1.select_one('div#content_journal')
                        if isi:
                            judul = get_text_or_na(isi, ['a.title', 'b.title', 'h2.title'])
                            penulis = get_data_from_span(isi, "Penulis")
                            pembimbing_pertama = get_data_from_span(isi, "Dosen Pembimbing I")
                            pembimbing_kedua = get_data_from_span(isi, "Dosen Pembimbing II")
                            abstrak_indonesia = get_abstract_robust(isi, ["Abstraksi", "Abstrak"])
                            abstrak_inggris = get_abstract_robust(isi, ["Abstraction", "Abstract", "ABSTRACT"])

                            all_data["penulis"].append(penulis)
                            all_data["judul"].append(judul)
                            all_data["pembimbing_pertama"].append(pembimbing_pertama)
                            all_data["pembimbing_kedua"].append(pembimbing_kedua)
                            all_data["abstrak_indonesia"].append(abstrak_indonesia)
                            all_data["abstrak_inggris"].append(abstrak_inggris)
                            all_data["prodi"].append(prodi['name'])

                            total_data_count += 1
                            print(f"Data ke-{total_data_count} berhasil diambil")
                    except Exception as e:
                        print(f"Gagal proses {jurnal_url}: {e}", file=sys.stderr)

                time.sleep(1)

            except Exception as e:
                print(f"Gagal ambil URL {url}: {e}", file=sys.stderr)
                continue

    df = pd.DataFrame(all_data)
    df.to_csv("pta_manajemen_raw.csv", index=False)
    print(f"✅ Scraping selesai. Total data: {total_data_count}")
    print("Data disimpan di pta_manajemen_raw.csv")
    return df

if __name__ == "__main__":
    scrape_manajemen_raw()
# Out:
# --- MULAI SCRAPING (RAW DATA) ---
# Ditemukan 207 halaman untuk Manajemen
# Data ke-1 berhasil diambil
# Data ke-2 berhasil diambil
# Data ke-3 berhasil diambil
# Data ke-4 berhasil diambil
# Data ke-5 berhasil diambil
# Data ke-6 berhasil diambil
# Data ke-7 berhasil diambil
# Data ke-8 berhasil diambil
# Data ke-9 berhasil diambil
# Data ke-10 berhasil diambil
# Data ke-11 berhasil diambil
# Data ke-12 berhasil diambil
# Data ke-13 berhasil diambil
# Data ke-14 berhasil diambil
# Data ke-15 berhasil diambil
# Data ke-16 berhasil diambil
# Data ke-17 berhasil diambil
# Data ke-18 berhasil diambil
# Data ke-19 berhasil diambil
# Data ke-20 berhasil diambil
# Data ke-21 berhasil diambil
# Data ke-22 berhasil diambil
# Data ke-23 berhasil diambil
# Data ke-24 berhasil diambil
# Data ke-25 berhasil diambil
# Data ke-26 berhasil diambil
# Data ke-27 berhasil diambil
# Data ke-28 berhasil diambil
# Data ke-29 berhasil diambil
# Data ke-30 berhasil diambil
# Data ke-31 berhasil diambil
# Data ke-32 berhasil diambil
# Data ke-33 berhasil diambil
# Data ke-34 berhasil diambil
# Data ke-35 berhasil diambil
# Data ke-36 berhasil diambil
# Data ke-37 berhasil diambil
# Data ke-38 berhasil diambil
# Data ke-39 berhasil diambil
# Data ke-40 berhasil diambil
# Data ke-41 berhasil diambil
# Data ke-42 berhasil diambil
# Data ke-43 berhasil diambil
# Data ke-44 berhasil diambil
# Data ke-45 berhasil diambil
# Data ke-46 berhasil diambil
# Data ke-47 berhasil diambil
# Data ke-48 berhasil diambil
# Data ke-49 berhasil diambil
# Data ke-50 berhasil diambil
# Data ke-51 berhasil diambil
# Data ke-52 berhasil diambil
# Data ke-53 berhasil diambil
# Data ke-54 berhasil diambil
# Data ke-55 berhasil diambil
# Data ke-56 berhasil diambil
# Data ke-57 berhasil diambil
# Data ke-58 berhasil diambil
# Data ke-59 berhasil diambil
# Data ke-60 berhasil diambil
# Data ke-61 berhasil diambil
# Data ke-62 berhasil diambil
# Data ke-63 berhasil diambil
# Data ke-64 berhasil diambil
# Data ke-65 berhasil diambil
# Data ke-66 berhasil diambil
# Data ke-67 berhasil diambil
# Data ke-68 berhasil diambil
# Data ke-69 berhasil diambil
# Data ke-70 berhasil diambil
# Data ke-71 berhasil diambil
# Data ke-72 berhasil diambil
# Data ke-73 berhasil diambil
# Data ke-74 berhasil diambil
# Data ke-75 berhasil diambil
# Data ke-76 berhasil diambil
# Data ke-77 berhasil diambil
# Data ke-78 berhasil diambil
# Data ke-79 berhasil diambil
# Data ke-80 berhasil diambil
# Data ke-81 berhasil diambil
# Data ke-82 berhasil diambil
# Data ke-83 berhasil diambil
# Data ke-84 berhasil diambil
# Data ke-85 berhasil diambil
# Data ke-86 berhasil diambil
# Data ke-87 berhasil diambil
# Data ke-88 berhasil diambil
# Data ke-89 berhasil diambil
# Data ke-90 berhasil diambil
# Data ke-91 berhasil diambil
# Data ke-92 berhasil diambil
# Data ke-93 berhasil diambil
# Data ke-94 berhasil diambil
# Data ke-95 berhasil diambil
# Data ke-96 berhasil diambil
# Data ke-97 berhasil diambil
# Data ke-98 berhasil diambil
# Data ke-99 berhasil diambil
# Data ke-100 berhasil diambil
# Data ke-101 berhasil diambil
# Data ke-102 berhasil diambil
# Data ke-103 berhasil diambil
# Data ke-104 berhasil diambil
# Data ke-105 berhasil diambil
# Data ke-106 berhasil diambil
# Data ke-107 berhasil diambil
# Data ke-108 berhasil diambil
# Data ke-109 berhasil diambil
# Data ke-110 berhasil diambil
# Data ke-111 berhasil diambil
# Data ke-112 berhasil diambil
# Data ke-113 berhasil diambil
# Data ke-114 berhasil diambil
# Data ke-115 berhasil diambil
# Data ke-116 berhasil diambil
# Data ke-117 berhasil diambil
# Data ke-118 berhasil diambil
# Data ke-119 berhasil diambil
# Data ke-120 berhasil diambil
# Data ke-121 berhasil diambil
# Data ke-122 berhasil diambil
# Data ke-123 berhasil diambil
# Data ke-124 berhasil diambil
# Data ke-125 berhasil diambil
# Data ke-126 berhasil diambil
# Data ke-127 berhasil diambil
# Data ke-128 berhasil diambil
# Data ke-129 berhasil diambil
# Data ke-130 berhasil diambil
# Data ke-131 berhasil diambil
# Data ke-132 berhasil diambil
# Data ke-133 berhasil diambil
# Data ke-134 berhasil diambil
# Data ke-135 berhasil diambil
# Data ke-136 berhasil diambil
# Data ke-137 berhasil diambil
# Data ke-138 berhasil diambil
# Data ke-139 berhasil diambil
# Data ke-140 berhasil diambil
# Data ke-141 berhasil diambil
# Data ke-142 berhasil diambil
# Data ke-143 berhasil diambil
# Data ke-144 berhasil diambil
# Data ke-145 berhasil diambil
# Data ke-146 berhasil diambil
# Data ke-147 berhasil diambil
# Data ke-148 berhasil diambil
# Data ke-149 berhasil diambil
# Data ke-150 berhasil diambil
# Data ke-151 berhasil diambil
# Data ke-152 berhasil diambil
# Data ke-153 berhasil diambil
# Data ke-154 berhasil diambil
# Data ke-155 berhasil diambil
# Data ke-156 berhasil diambil
# Data ke-157 berhasil diambil
# Data ke-158 berhasil diambil
# Data ke-159 berhasil diambil
# Data ke-160 berhasil diambil
# Data ke-161 berhasil diambil
# Data ke-162 berhasil diambil
# Data ke-163 berhasil diambil
# Data ke-164 berhasil diambil
# Data ke-165 berhasil diambil
# Data ke-166 berhasil diambil
# Data ke-167 berhasil diambil
# Data ke-168 berhasil diambil
# Data ke-169 berhasil diambil
# Data ke-170 berhasil diambil
# Data ke-171 berhasil diambil
# Data ke-172 berhasil diambil
# Data ke-173 berhasil diambil
# Data ke-174 berhasil diambil
# Data ke-175 berhasil diambil
# Data ke-176 berhasil diambil
# Data ke-177 berhasil diambil
# Data ke-178 berhasil diambil
# Data ke-179 berhasil diambil
# Data ke-180 berhasil diambil
# Data ke-181 berhasil diambil
# Data ke-182 berhasil diambil
# Data ke-183 berhasil diambil
# Data ke-184 berhasil diambil
# Data ke-185 berhasil diambil
# Data ke-186 berhasil diambil
# Data ke-187 berhasil diambil
# Data ke-188 berhasil diambil
# Data ke-189 berhasil diambil
# Data ke-190 berhasil diambil
# Data ke-191 berhasil diambil
# Data ke-192 berhasil diambil
# Data ke-193 berhasil diambil
# Data ke-194 berhasil diambil
# Data ke-195 berhasil diambil
# Data ke-196 berhasil diambil
# Data ke-197 berhasil diambil
# Data ke-198 berhasil diambil
# Data ke-199 berhasil diambil
# Data ke-200 berhasil diambil
# Data ke-201 berhasil diambil
# Data ke-202 berhasil diambil
# Data ke-203 berhasil diambil
# Data ke-204 berhasil diambil
# Data ke-205 berhasil diambil
# Data ke-206 berhasil diambil
# Data ke-207 berhasil diambil
# Data ke-208 berhasil diambil
# Data ke-209 berhasil diambil
# Data ke-210 berhasil diambil
# Data ke-211 berhasil diambil
# Data ke-212 berhasil diambil
# Data ke-213 berhasil diambil
# Data ke-214 berhasil diambil
# Data ke-215 berhasil diambil
# Data ke-216 berhasil diambil
# Data ke-217 berhasil diambil
# Data ke-218 berhasil diambil
# Data ke-219 berhasil diambil
# Data ke-220 berhasil diambil
# Data ke-221 berhasil diambil
# Data ke-222 berhasil diambil
# Data ke-223 berhasil diambil
# Data ke-224 berhasil diambil
# Data ke-225 berhasil diambil
# Data ke-226 berhasil diambil
# Data ke-227 berhasil diambil
# Data ke-228 berhasil diambil
# Data ke-229 berhasil diambil
# Data ke-230 berhasil diambil
# Data ke-231 berhasil diambil
# Data ke-232 berhasil diambil
# Data ke-233 berhasil diambil
# Data ke-234 berhasil diambil
# Data ke-235 berhasil diambil
# Data ke-236 berhasil diambil
# Data ke-237 berhasil diambil
# Data ke-238 berhasil diambil
# Data ke-239 berhasil diambil
# Data ke-240 berhasil diambil
# Data ke-241 berhasil diambil
# Data ke-242 berhasil diambil
# Data ke-243 berhasil diambil
# Data ke-244 berhasil diambil
# Data ke-245 berhasil diambil
# Data ke-246 berhasil diambil
# Data ke-247 berhasil diambil
# Data ke-248 berhasil diambil
# Data ke-249 berhasil diambil
# Data ke-250 berhasil diambil
# Data ke-251 berhasil diambil
# Data ke-252 berhasil diambil
# Data ke-253 berhasil diambil
# Data ke-254 berhasil diambil
# Data ke-255 berhasil diambil
# Data ke-256 berhasil diambil
# Data ke-257 berhasil diambil
# Data ke-258 berhasil diambil
# Data ke-259 berhasil diambil
# Data ke-260 berhasil diambil
# Data ke-261 berhasil diambil
# Data ke-262 berhasil diambil
# Data ke-263 berhasil diambil
# Data ke-264 berhasil diambil
# Data ke-265 berhasil diambil
# Data ke-266 berhasil diambil
# Data ke-267 berhasil diambil
# Data ke-268 berhasil diambil
# Data ke-269 berhasil diambil
# Data ke-270 berhasil diambil
# Data ke-271 berhasil diambil
# Data ke-272 berhasil diambil
# Data ke-273 berhasil diambil
# Data ke-274 berhasil diambil
# Data ke-275 berhasil diambil
# Data ke-276 berhasil diambil
# Data ke-277 berhasil diambil
# Data ke-278 berhasil diambil
# Data ke-279 berhasil diambil
# Data ke-280 berhasil diambil
# Data ke-281 berhasil diambil
# Data ke-282 berhasil diambil
# Data ke-283 berhasil diambil
# Data ke-284 berhasil diambil
# Data ke-285 berhasil diambil
# Data ke-286 berhasil diambil
# Data ke-287 berhasil diambil
# Data ke-288 berhasil diambil
# Data ke-289 berhasil diambil
# Data ke-290 berhasil diambil
# Data ke-291 berhasil diambil
# Data ke-292 berhasil diambil
# Data ke-293 berhasil diambil
# Data ke-294 berhasil diambil
# Data ke-295 berhasil diambil
# Data ke-296 berhasil diambil
# Data ke-297 berhasil diambil
# Data ke-298 berhasil diambil
# Data ke-299 berhasil diambil
# Data ke-300 berhasil diambil
# Data ke-301 berhasil diambil
# Data ke-302 berhasil diambil
# Data ke-303 berhasil diambil
# Data ke-304 berhasil diambil
# Data ke-305 berhasil diambil
# Data ke-306 berhasil diambil
# Data ke-307 berhasil diambil
# Data ke-308 berhasil diambil
# Data ke-309 berhasil diambil
# Data ke-310 berhasil diambil
# Data ke-311 berhasil diambil
# Data ke-312 berhasil diambil
# Data ke-313 berhasil diambil
# Data ke-314 berhasil diambil
# Data ke-315 berhasil diambil
# Data ke-316 berhasil diambil
# Data ke-317 berhasil diambil
# Data ke-318 berhasil diambil
# Data ke-319 berhasil diambil
# Data ke-320 berhasil diambil
# Data ke-321 berhasil diambil
# Data ke-322 berhasil diambil
# Data ke-323 berhasil diambil
# Data ke-324 berhasil diambil
# Data ke-325 berhasil diambil
# Data ke-326 berhasil diambil
# Data ke-327 berhasil diambil
# Data ke-328 berhasil diambil
# Data ke-329 berhasil diambil
# Data ke-330 berhasil diambil
# Data ke-331 berhasil diambil
# Data ke-332 berhasil diambil
# Data ke-333 berhasil diambil
# Data ke-334 berhasil diambil
# Data ke-335 berhasil diambil
# Data ke-336 berhasil diambil
# Data ke-337 berhasil diambil
# Data ke-338 berhasil diambil
# Data ke-339 berhasil diambil
# Data ke-340 berhasil diambil
# Data ke-341 berhasil diambil
# Data ke-342 berhasil diambil
# Data ke-343 berhasil diambil
# Data ke-344 berhasil diambil
# Data ke-345 berhasil diambil
# Data ke-346 berhasil diambil
# Data ke-347 berhasil diambil
# Data ke-348 berhasil diambil
# Data ke-349 berhasil diambil
# Data ke-350 berhasil diambil
# Data ke-351 berhasil diambil
# Data ke-352 berhasil diambil
# Data ke-353 berhasil diambil
# Data ke-354 berhasil diambil
# Data ke-355 berhasil diambil
# Data ke-356 berhasil diambil
# Data ke-357 berhasil diambil
# Data ke-358 berhasil diambil
# Data ke-359 berhasil diambil
# Data ke-360 berhasil diambil
# Data ke-361 berhasil diambil
# Data ke-362 berhasil diambil
# Data ke-363 berhasil diambil
# Data ke-364 berhasil diambil
# Data ke-365 berhasil diambil
# Data ke-366 berhasil diambil
# Data ke-367 berhasil diambil
# Data ke-368 berhasil diambil
# Data ke-369 berhasil diambil
# Data ke-370 berhasil diambil
# Data ke-371 berhasil diambil
# Data ke-372 berhasil diambil
# Data ke-373 berhasil diambil
# Data ke-374 berhasil diambil
# Data ke-375 berhasil diambil
# Data ke-376 berhasil diambil
# Data ke-377 berhasil diambil
# Data ke-378 berhasil diambil
# Data ke-379 berhasil diambil
# Data ke-380 berhasil diambil
# Data ke-381 berhasil diambil
# Data ke-382 berhasil diambil
# Data ke-383 berhasil diambil
# Data ke-384 berhasil diambil
# Data ke-385 berhasil diambil
# Data ke-386 berhasil diambil
# Data ke-387 berhasil diambil
# Data ke-388 berhasil diambil
# Data ke-389 berhasil diambil
# Data ke-390 berhasil diambil
# Data ke-391 berhasil diambil
# Data ke-392 berhasil diambil
# Data ke-393 berhasil diambil
# Data ke-394 berhasil diambil
# Data ke-395 berhasil diambil
# Data ke-396 berhasil diambil
# Data ke-397 berhasil diambil
# Data ke-398 berhasil diambil
# Data ke-399 berhasil diambil
# Data ke-400 berhasil diambil
# Data ke-401 berhasil diambil
# Data ke-402 berhasil diambil
# Data ke-403 berhasil diambil
# Data ke-404 berhasil diambil
# Data ke-405 berhasil diambil
# Data ke-406 berhasil diambil
# Data ke-407 berhasil diambil
# Data ke-408 berhasil diambil
# Data ke-409 berhasil diambil
# Data ke-410 berhasil diambil
# Data ke-411 berhasil diambil
# Data ke-412 berhasil diambil
# Data ke-413 berhasil diambil
# Data ke-414 berhasil diambil
# Data ke-415 berhasil diambil
# Data ke-416 berhasil diambil
# Data ke-417 berhasil diambil
# Data ke-418 berhasil diambil
# Data ke-419 berhasil diambil
# Data ke-420 berhasil diambil
# Data ke-421 berhasil diambil
# Data ke-422 berhasil diambil
# Data ke-423 berhasil diambil
# Data ke-424 berhasil diambil
# Data ke-425 berhasil diambil
# Data ke-426 berhasil diambil
# Data ke-427 berhasil diambil
# Data ke-428 berhasil diambil
# Data ke-429 berhasil diambil
# Data ke-430 berhasil diambil
# Data ke-431 berhasil diambil
# Data ke-432 berhasil diambil
# Data ke-433 berhasil diambil
# Data ke-434 berhasil diambil
# Data ke-435 berhasil diambil
# Data ke-436 berhasil diambil
# Data ke-437 berhasil diambil
# Data ke-438 berhasil diambil
# Data ke-439 berhasil diambil
# Data ke-440 berhasil diambil
# Data ke-441 berhasil diambil
# Data ke-442 berhasil diambil
# Data ke-443 berhasil diambil
# Data ke-444 berhasil diambil
# Data ke-445 berhasil diambil
# Data ke-446 berhasil diambil
# Data ke-447 berhasil diambil
# Data ke-448 berhasil diambil
# Data ke-449 berhasil diambil
# Data ke-450 berhasil diambil
# Data ke-451 berhasil diambil
# Data ke-452 berhasil diambil
# Data ke-453 berhasil diambil
# Data ke-454 berhasil diambil
# Data ke-455 berhasil diambil
# Data ke-456 berhasil diambil
# Data ke-457 berhasil diambil
# Data ke-458 berhasil diambil
# Data ke-459 berhasil diambil
# Data ke-460 berhasil diambil
# Data ke-461 berhasil diambil
# Data ke-462 berhasil diambil
# Data ke-463 berhasil diambil
# Data ke-464 berhasil diambil
# Data ke-465 berhasil diambil
# Data ke-466 berhasil diambil
# Data ke-467 berhasil diambil
# Data ke-468 berhasil diambil
# Data ke-469 berhasil diambil
# Data ke-470 berhasil diambil
# Data ke-471 berhasil diambil
# Data ke-472 berhasil diambil
# Data ke-473 berhasil diambil
# Data ke-474 berhasil diambil
# Data ke-475 berhasil diambil
# Data ke-476 berhasil diambil
# Data ke-477 berhasil diambil
# Data ke-478 berhasil diambil
# Data ke-479 berhasil diambil
# Data ke-480 berhasil diambil
# Data ke-481 berhasil diambil
# Data ke-482 berhasil diambil
# Data ke-483 berhasil diambil
# Data ke-484 berhasil diambil
# Data ke-485 berhasil diambil
# Data ke-486 berhasil diambil
# Data ke-487 berhasil diambil
# Data ke-488 berhasil diambil
# Data ke-489 berhasil diambil
# Data ke-490 berhasil diambil
# Data ke-491 berhasil diambil
# Data ke-492 berhasil diambil
# Data ke-493 berhasil diambil
# Data ke-494 berhasil diambil
# Data ke-495 berhasil diambil
# Data ke-496 berhasil diambil
# Data ke-497 berhasil diambil
# Data ke-498 berhasil diambil
# Data ke-499 berhasil diambil
# Data ke-500 berhasil diambil
# Data ke-501 berhasil diambil
# Data ke-502 berhasil diambil
# Data ke-503 berhasil diambil
# Data ke-504 berhasil diambil
# Data ke-505 berhasil diambil
# Data ke-506 berhasil diambil
# Data ke-507 berhasil diambil
# Data ke-508 berhasil diambil
# Data ke-509 berhasil diambil
# Data ke-510 berhasil diambil
# Data ke-511 berhasil diambil
# Data ke-512 berhasil diambil
# Data ke-513 berhasil diambil
# Data ke-514 berhasil diambil
# Data ke-515 berhasil diambil
# Data ke-516 berhasil diambil
# Data ke-517 berhasil diambil
# Data ke-518 berhasil diambil
# Data ke-519 berhasil diambil
# Data ke-520 berhasil diambil
# Data ke-521 berhasil diambil
# Data ke-522 berhasil diambil
# Data ke-523 berhasil diambil
# Data ke-524 berhasil diambil
# Data ke-525 berhasil diambil
# Data ke-526 berhasil diambil
# Data ke-527 berhasil diambil
# Data ke-528 berhasil diambil
# Data ke-529 berhasil diambil
# Data ke-530 berhasil diambil
# Data ke-531 berhasil diambil
# Data ke-532 berhasil diambil
# Data ke-533 berhasil diambil
# Data ke-534 berhasil diambil
# Data ke-535 berhasil diambil
# Data ke-536 berhasil diambil
# Data ke-537 berhasil diambil
# Data ke-538 berhasil diambil
# Data ke-539 berhasil diambil
# Data ke-540 berhasil diambil
# Data ke-541 berhasil diambil
# Data ke-542 berhasil diambil
# Data ke-543 berhasil diambil
# Data ke-544 berhasil diambil
# Data ke-545 berhasil diambil
# Data ke-546 berhasil diambil
# Data ke-547 berhasil diambil
# Data ke-548 berhasil diambil
# Data ke-549 berhasil diambil
# Data ke-550 berhasil diambil
# Data ke-551 berhasil diambil
# Data ke-552 berhasil diambil
# Data ke-553 berhasil diambil
# Data ke-554 berhasil diambil
# Data ke-555 berhasil diambil
# Data ke-556 berhasil diambil
# Data ke-557 berhasil diambil
# Data ke-558 berhasil diambil
# Data ke-559 berhasil diambil
# Data ke-560 berhasil diambil
# Data ke-561 berhasil diambil
# Data ke-562 berhasil diambil
# Data ke-563 berhasil diambil
# Data ke-564 berhasil diambil
# Data ke-565 berhasil diambil
# Data ke-566 berhasil diambil
# Data ke-567 berhasil diambil
# Data ke-568 berhasil diambil
# Data ke-569 berhasil diambil
# Data ke-570 berhasil diambil
# Data ke-571 berhasil diambil
# Data ke-572 berhasil diambil
# Data ke-573 berhasil diambil
# Data ke-574 berhasil diambil
# Data ke-575 berhasil diambil
# Data ke-576 berhasil diambil
# Data ke-577 berhasil diambil
# Data ke-578 berhasil diambil
# Data ke-579 berhasil diambil
# Data ke-580 berhasil diambil
# Data ke-581 berhasil diambil
# Data ke-582 berhasil diambil
# Data ke-583 berhasil diambil
# Data ke-584 berhasil diambil
# Data ke-585 berhasil diambil
# Data ke-586 berhasil diambil
# Data ke-587 berhasil diambil
# Data ke-588 berhasil diambil
# Data ke-589 berhasil diambil
# Data ke-590 berhasil diambil
# Data ke-591 berhasil diambil
# Data ke-592 berhasil diambil
# Data ke-593 berhasil diambil
# Data ke-594 berhasil diambil
# Data ke-595 berhasil diambil
# Data ke-596 berhasil diambil
# Data ke-597 berhasil diambil
# Data ke-598 berhasil diambil
# Data ke-599 berhasil diambil
# Data ke-600 berhasil diambil
# Data ke-601 berhasil diambil
# Data ke-602 berhasil diambil
# Data ke-603 berhasil diambil
# Data ke-604 berhasil diambil
# Data ke-605 berhasil diambil
# Data ke-606 berhasil diambil
# Data ke-607 berhasil diambil
# Data ke-608 berhasil diambil
# Data ke-609 berhasil diambil
# Data ke-610 berhasil diambil
# Data ke-611 berhasil diambil
# Data ke-612 berhasil diambil
# Data ke-613 berhasil diambil
# Data ke-614 berhasil diambil
# Data ke-615 berhasil diambil
# Data ke-616 berhasil diambil
# Data ke-617 berhasil diambil
# Data ke-618 berhasil diambil
# Data ke-619 berhasil diambil
# Data ke-620 berhasil diambil
# Data ke-621 berhasil diambil
# Data ke-622 berhasil diambil
# Data ke-623 berhasil diambil
# Data ke-624 berhasil diambil
# Data ke-625 berhasil diambil
# Data ke-626 berhasil diambil
# Data ke-627 berhasil diambil
# Data ke-628 berhasil diambil
# Data ke-629 berhasil diambil
# Data ke-630 berhasil diambil
# Data ke-631 berhasil diambil
# Data ke-632 berhasil diambil
# Data ke-633 berhasil diambil
# Data ke-634 berhasil diambil
# Data ke-635 berhasil diambil
# Data ke-636 berhasil diambil
# Data ke-637 berhasil diambil
# Data ke-638 berhasil diambil
# Data ke-639 berhasil diambil
# Data ke-640 berhasil diambil
# Data ke-641 berhasil diambil
# Data ke-642 berhasil diambil
# Data ke-643 berhasil diambil
# Data ke-644 berhasil diambil
# Data ke-645 berhasil diambil
# Data ke-646 berhasil diambil
# Data ke-647 berhasil diambil
# Data ke-648 berhasil diambil
# Data ke-649 berhasil diambil
# Data ke-650 berhasil diambil
# Data ke-651 berhasil diambil
# Data ke-652 berhasil diambil
# Data ke-653 berhasil diambil
# Data ke-654 berhasil diambil
# Data ke-655 berhasil diambil
# Data ke-656 berhasil diambil
# Data ke-657 berhasil diambil
# Data ke-658 berhasil diambil
# Data ke-659 berhasil diambil
# Data ke-660 berhasil diambil
# Data ke-661 berhasil diambil
# Data ke-662 berhasil diambil
# Data ke-663 berhasil diambil
# Data ke-664 berhasil diambil
# Data ke-665 berhasil diambil
# Data ke-666 berhasil diambil
# Data ke-667 berhasil diambil
# Data ke-668 berhasil diambil
# Data ke-669 berhasil diambil
# Data ke-670 berhasil diambil
# Data ke-671 berhasil diambil
# Data ke-672 berhasil diambil
# Data ke-673 berhasil diambil
# Data ke-674 berhasil diambil
# Data ke-675 berhasil diambil
# Data ke-676 berhasil diambil
# Data ke-677 berhasil diambil
# Data ke-678 berhasil diambil
# Data ke-679 berhasil diambil
# Data ke-680 berhasil diambil
# Data ke-681 berhasil diambil
# Data ke-682 berhasil diambil
# Data ke-683 berhasil diambil
# Data ke-684 berhasil diambil
# Data ke-685 berhasil diambil
# Data ke-686 berhasil diambil
# Data ke-687 berhasil diambil
# Data ke-688 berhasil diambil
# Data ke-689 berhasil diambil
# Data ke-690 berhasil diambil
# Data ke-691 berhasil diambil
# Data ke-692 berhasil diambil
# Data ke-693 berhasil diambil
# Data ke-694 berhasil diambil
# Data ke-695 berhasil diambil
# Data ke-696 berhasil diambil
# Data ke-697 berhasil diambil
# Data ke-698 berhasil diambil
# Data ke-699 berhasil diambil
# Data ke-700 berhasil diambil
# Data ke-701 berhasil diambil
# Data ke-702 berhasil diambil
# Data ke-703 berhasil diambil
# Data ke-704 berhasil diambil
# Data ke-705 berhasil diambil
# Data ke-706 berhasil diambil
# Data ke-707 berhasil diambil
# Data ke-708 berhasil diambil
# Data ke-709 berhasil diambil
# Data ke-710 berhasil diambil
# Data ke-711 berhasil diambil
# Data ke-712 berhasil diambil
# Data ke-713 berhasil diambil
# Data ke-714 berhasil diambil
# Data ke-715 berhasil diambil
# Data ke-716 berhasil diambil
# Data ke-717 berhasil diambil
# Data ke-718 berhasil diambil
# Data ke-719 berhasil diambil
# Data ke-720 berhasil diambil
# Data ke-721 berhasil diambil
# Data ke-722 berhasil diambil
# Data ke-723 berhasil diambil
# Data ke-724 berhasil diambil
# Data ke-725 berhasil diambil
# Data ke-726 berhasil diambil
# Data ke-727 berhasil diambil
# Data ke-728 berhasil diambil
# Data ke-729 berhasil diambil
# Data ke-730 berhasil diambil
# Data ke-731 berhasil diambil
# Data ke-732 berhasil diambil
# Data ke-733 berhasil diambil
# Data ke-734 berhasil diambil
# Data ke-735 berhasil diambil
# Data ke-736 berhasil diambil
# Data ke-737 berhasil diambil
# Data ke-738 berhasil diambil
# Data ke-739 berhasil diambil
# Data ke-740 berhasil diambil
# Data ke-741 berhasil diambil
# Data ke-742 berhasil diambil
# Data ke-743 berhasil diambil
# Data ke-744 berhasil diambil
# Data ke-745 berhasil diambil
# Data ke-746 berhasil diambil
# Data ke-747 berhasil diambil
# Data ke-748 berhasil diambil
# Data ke-749 berhasil diambil
# Data ke-750 berhasil diambil
# Data ke-751 berhasil diambil
# Data ke-752 berhasil diambil
# Data ke-753 berhasil diambil
# Data ke-754 berhasil diambil
# Data ke-755 berhasil diambil
# Data ke-756 berhasil diambil
# Data ke-757 berhasil diambil
# Data ke-758 berhasil diambil
# Data ke-759 berhasil diambil
# Data ke-760 berhasil diambil
# Data ke-761 berhasil diambil
# Data ke-762 berhasil diambil
# Data ke-763 berhasil diambil
# Data ke-764 berhasil diambil
# Data ke-765 berhasil diambil
# Data ke-766 berhasil diambil
# Data ke-767 berhasil diambil
# Data ke-768 berhasil diambil
# Data ke-769 berhasil diambil
# Data ke-770 berhasil diambil
# Data ke-771 berhasil diambil
# Data ke-772 berhasil diambil
# Data ke-773 berhasil diambil
# Data ke-774 berhasil diambil
# Data ke-775 berhasil diambil
# Data ke-776 berhasil diambil
# Data ke-777 berhasil diambil
# Data ke-778 berhasil diambil
# Data ke-779 berhasil diambil
# Data ke-780 berhasil diambil
# Data ke-781 berhasil diambil
# Data ke-782 berhasil diambil
# Data ke-783 berhasil diambil
# Data ke-784 berhasil diambil
# Data ke-785 berhasil diambil
# Data ke-786 berhasil diambil
# Data ke-787 berhasil diambil
# Data ke-788 berhasil diambil
# Data ke-789 berhasil diambil
# Data ke-790 berhasil diambil
# Data ke-791 berhasil diambil
# Data ke-792 berhasil diambil
# Data ke-793 berhasil diambil
# Data ke-794 berhasil diambil
# Data ke-795 berhasil diambil
# Data ke-796 berhasil diambil
# Data ke-797 berhasil diambil
# Data ke-798 berhasil diambil
# Data ke-799 berhasil diambil
# Data ke-800 berhasil diambil
# Data ke-801 berhasil diambil
# Data ke-802 berhasil diambil
# Data ke-803 berhasil diambil
# Data ke-804 berhasil diambil
# Data ke-805 berhasil diambil
# Data ke-806 berhasil diambil
# Data ke-807 berhasil diambil
# Data ke-808 berhasil diambil
# Data ke-809 berhasil diambil
# Data ke-810 berhasil diambil
# Data ke-811 berhasil diambil
# Data ke-812 berhasil diambil
# Data ke-813 berhasil diambil
# Data ke-814 berhasil diambil
# Data ke-815 berhasil diambil
# Data ke-816 berhasil diambil
# Data ke-817 berhasil diambil
# Data ke-818 berhasil diambil
# Data ke-819 berhasil diambil
# Data ke-820 berhasil diambil
# Data ke-821 berhasil diambil
# Data ke-822 berhasil diambil
# Data ke-823 berhasil diambil
# Data ke-824 berhasil diambil
# Data ke-825 berhasil diambil
# Data ke-826 berhasil diambil
# Data ke-827 berhasil diambil
# Data ke-828 berhasil diambil
# Data ke-829 berhasil diambil
# Data ke-830 berhasil diambil
# Data ke-831 berhasil diambil
# Data ke-832 berhasil diambil
# Data ke-833 berhasil diambil
# Data ke-834 berhasil diambil
# Data ke-835 berhasil diambil
# Data ke-836 berhasil diambil
# Data ke-837 berhasil diambil
# Data ke-838 berhasil diambil
# Data ke-839 berhasil diambil
# Data ke-840 berhasil diambil
# Data ke-841 berhasil diambil
# Data ke-842 berhasil diambil
# Data ke-843 berhasil diambil
# Data ke-844 berhasil diambil
# Data ke-845 berhasil diambil
# Data ke-846 berhasil diambil
# Data ke-847 berhasil diambil
# Data ke-848 berhasil diambil
# Data ke-849 berhasil diambil
# Data ke-850 berhasil diambil
# Data ke-851 berhasil diambil
# Data ke-852 berhasil diambil
# Data ke-853 berhasil diambil
# Data ke-854 berhasil diambil
# Data ke-855 berhasil diambil
# Data ke-856 berhasil diambil
# Data ke-857 berhasil diambil
# Data ke-858 berhasil diambil
# Data ke-859 berhasil diambil
# Data ke-860 berhasil diambil
# Data ke-861 berhasil diambil
# Data ke-862 berhasil diambil
# Data ke-863 berhasil diambil
# Data ke-864 berhasil diambil
# Data ke-865 berhasil diambil
# Data ke-866 berhasil diambil
# Data ke-867 berhasil diambil
# Data ke-868 berhasil diambil
# Data ke-869 berhasil diambil
# Data ke-870 berhasil diambil
# Data ke-871 berhasil diambil
# Data ke-872 berhasil diambil
# Data ke-873 berhasil diambil
# Data ke-874 berhasil diambil
# Data ke-875 berhasil diambil
# Data ke-876 berhasil diambil
# Data ke-877 berhasil diambil
# Data ke-878 berhasil diambil
# Data ke-879 berhasil diambil
# Data ke-880 berhasil diambil
# Data ke-881 berhasil diambil
# Data ke-882 berhasil diambil
# Data ke-883 berhasil diambil
# Data ke-884 berhasil diambil
# Data ke-885 berhasil diambil
# Data ke-886 berhasil diambil
# Data ke-887 berhasil diambil
# Data ke-888 berhasil diambil
# Data ke-889 berhasil diambil
# Data ke-890 berhasil diambil
# Data ke-891 berhasil diambil
# Data ke-892 berhasil diambil
# Data ke-893 berhasil diambil
# Data ke-894 berhasil diambil
# Data ke-895 berhasil diambil
# Data ke-896 berhasil diambil
# Data ke-897 berhasil diambil
# Data ke-898 berhasil diambil
# Data ke-899 berhasil diambil
# Data ke-900 berhasil diambil
# Data ke-901 berhasil diambil
# Data ke-902 berhasil diambil
# Data ke-903 berhasil diambil
# Data ke-904 berhasil diambil
# Data ke-905 berhasil diambil
# Data ke-906 berhasil diambil
# Data ke-907 berhasil diambil
# Data ke-908 berhasil diambil
# Data ke-909 berhasil diambil
# Data ke-910 berhasil diambil
# Data ke-911 berhasil diambil
# Data ke-912 berhasil diambil
# Data ke-913 berhasil diambil
# Data ke-914 berhasil diambil
# Data ke-915 berhasil diambil
# Data ke-916 berhasil diambil
# Data ke-917 berhasil diambil
# Data ke-918 berhasil diambil
# Data ke-919 berhasil diambil
# Data ke-920 berhasil diambil
# Data ke-921 berhasil diambil
# Data ke-922 berhasil diambil
# Data ke-923 berhasil diambil
# Data ke-924 berhasil diambil
# Data ke-925 berhasil diambil
# Data ke-926 berhasil diambil
# Data ke-927 berhasil diambil
# Data ke-928 berhasil diambil
# Data ke-929 berhasil diambil
# Data ke-930 berhasil diambil
# Data ke-931 berhasil diambil
# Data ke-932 berhasil diambil
# Data ke-933 berhasil diambil
# Data ke-934 berhasil diambil
# Data ke-935 berhasil diambil
# Data ke-936 berhasil diambil
# Data ke-937 berhasil diambil
# Data ke-938 berhasil diambil
# Data ke-939 berhasil diambil
# Data ke-940 berhasil diambil
# Data ke-941 berhasil diambil
# Data ke-942 berhasil diambil
# Data ke-943 berhasil diambil
# Data ke-944 berhasil diambil
# Data ke-945 berhasil diambil
# Data ke-946 berhasil diambil
# Data ke-947 berhasil diambil
# Data ke-948 berhasil diambil
# Data ke-949 berhasil diambil
# Data ke-950 berhasil diambil
# Data ke-951 berhasil diambil
# Data ke-952 berhasil diambil
# Data ke-953 berhasil diambil
# Data ke-954 berhasil diambil
# Data ke-955 berhasil diambil
# Data ke-956 berhasil diambil
# Data ke-957 berhasil diambil
# Data ke-958 berhasil diambil
# Data ke-959 berhasil diambil
# Data ke-960 berhasil diambil
# Data ke-961 berhasil diambil
# Data ke-962 berhasil diambil
# Data ke-963 berhasil diambil
# Data ke-964 berhasil diambil
# Data ke-965 berhasil diambil
# Data ke-966 berhasil diambil
# Data ke-967 berhasil diambil
# Data ke-968 berhasil diambil
# Data ke-969 berhasil diambil
# Data ke-970 berhasil diambil
# Data ke-971 berhasil diambil
# Data ke-972 berhasil diambil
# Data ke-973 berhasil diambil
# Data ke-974 berhasil diambil
# Data ke-975 berhasil diambil
# Data ke-976 berhasil diambil
# Data ke-977 berhasil diambil
# Data ke-978 berhasil diambil
# Data ke-979 berhasil diambil
# Data ke-980 berhasil diambil
# Data ke-981 berhasil diambil
# Data ke-982 berhasil diambil
# Data ke-983 berhasil diambil
# Data ke-984 berhasil diambil
# Data ke-985 berhasil diambil
# Data ke-986 berhasil diambil
# Data ke-987 berhasil diambil
# Data ke-988 berhasil diambil
# Data ke-989 berhasil diambil
# Data ke-990 berhasil diambil
# Data ke-991 berhasil diambil
# Data ke-992 berhasil diambil
# Data ke-993 berhasil diambil
# Data ke-994 berhasil diambil
# Data ke-995 berhasil diambil
# Data ke-996 berhasil diambil
# Data ke-997 berhasil diambil
# Data ke-998 berhasil diambil
# Data ke-999 berhasil diambil
# Data ke-1000 berhasil diambil
# Data ke-1001 berhasil diambil
# Data ke-1002 berhasil diambil
# Data ke-1003 berhasil diambil
# Data ke-1004 berhasil diambil
# Data ke-1005 berhasil diambil
# Data ke-1006 berhasil diambil
# Data ke-1007 berhasil diambil
# Data ke-1008 berhasil diambil
# Data ke-1009 berhasil diambil
# Data ke-1010 berhasil diambil
# Data ke-1011 berhasil diambil
# Data ke-1012 berhasil diambil
# Data ke-1013 berhasil diambil
# Data ke-1014 berhasil diambil
# Data ke-1015 berhasil diambil
# Data ke-1016 berhasil diambil
# Data ke-1017 berhasil diambil
# Data ke-1018 berhasil diambil
# Data ke-1019 berhasil diambil
# Data ke-1020 berhasil diambil
# Data ke-1021 berhasil diambil
# Data ke-1022 berhasil diambil
# Data ke-1023 berhasil diambil
# Data ke-1024 berhasil diambil
# Data ke-1025 berhasil diambil
# Data ke-1026 berhasil diambil
# Data ke-1027 berhasil diambil
# Data ke-1028 berhasil diambil
# Data ke-1029 berhasil diambil
# Data ke-1030 berhasil diambil
# Data ke-1031 berhasil diambil
# ✅ Scraping selesai. Total data: 1031
# Data disimpan di pta_manajemen_raw.csv

# %%
import pandas as pd

# baca file hasil scraping
df_raw = pd.read_csv("pta_manajemen_raw.csv")

print("=== DATA HASIL CRAWLING (RAW) ===")
print(df_raw.head(10))   # tampilkan 10 baris pertama
print("\nJumlah data:", len(df_raw))
# Out:
# === DATA HASIL CRAWLING (RAW) ===
#                    penulis                                              judul  \
# 0                  SATIYAH  PENGARUH FAKTOR-FAKTOR PELATIHAN DAN PENGEMBAN...
# 1                  Faishal  ANALISIS PERSEPSI BRAND ASSOCIATION MENURUT PE...
# 2          Wahyu Kurniawan  PENGARUH GAYA KEPEMIMPINAN DEMOKRATIK TERHADAP...
# 3   Muhammad Zakaria Utomo  Pengukuran Website Quality Pada Situs Sistem A...
# 4  Hendri Wahyudi Prayitno  PENGARUH KEPEMIMPINAN DAN KOMPENSASI TERHADAP ...
# 5               Aththaariq  PENGARUH KOMPETENSI DOSEN TERHADAP KINERJA DOS...
# 6           Haryono Arifin  PENGARUH PERILAKU KONSUMEN TERHADAP KEPUTUSAN ...
# 7       Dharma Abidin Syah  PENGARUH TIPE KEPEMIMPINAN TERHADAP PRESTASI K...
# 8            Toni Budianto  PENGARUH DIMENSI KUALITAS PELAYANAN TERHADAP K...
# 9     Iwan Kurniawan Gomes  ANALISIS TINGKAT RISIKO KREDIT \r\nPADA PD. BP...
#
#                    pembimbing_pertama                        pembimbing_kedua  \
# 0  Dra. Hj. S. Anugrahini Irawati, MM         Helmi Buyung Aulia,S,ST.SE,M.MT
# 1                     Nurita Andriani                    Yustina Chrismardani
# 2      Dr. Dra. Hj. Iriani Ismail, MM      Dra. Hj. S. Anugrahini Irawati, MM
# 3         Dr. Ir. Nurita Andriani, MM               Nirma Kurriwati, SP, M.Si
# 4   Dra. Hj. S Anugrahini Irawati, MM          Helmi Buyung Aulia,S,ST,SE,.MT
# 5      Dr.RM Moch Wispandono,.S.E,.MS  Dr. Muhammad Alkirom Wildan,S.E.,M.Si.
# 6          Dr. Ir Nurita Andriani, MM             Nirma Kurriwati, S.P., M.Si
# 7      Drs. Ec. Mudji Kuswinarno M,Si                           Faidal SE, MM
# 8   Bambang Setiyo Pambudi, S.E., MM.                    Fathor AS, S.E., MM.
# 9     Drs. Ec. Makhmud Zulkifli, M.Si                 Echsan Gani, S.E., M.SI
#
#                                    abstrak_indonesia  \
# 0  ABSTRAK\r\nSatiyah, Pengaruh Faktor-faktor Pel...
# 1  Tujuan penelitian ini adalah untuk mengetahui ...
# 2                                                NaN
# 3  Aplikasi nyata pemanfaatan teknologi informasi...
# 4  Abstrak\r\nPenelitian ini menggunakan metode k...
# 5  Abstrak\r\n\r\nAththaariq, Pengaruh Kompetensi...
# 6  ABSTRAK\r\nHaryono Arifin, Pengaruh Perilaku K...
# 7  ABSTRAK\r\n\tDharma Abidin Syah,Kesimpulan: (1...
# 8  ABSTRAK\r\n\r\nTujuan penelitian ini adalah un...
# 9  Hasil dari penelitian ini dari perhitungan Cre...
#
#                                      abstrak_inggris      prodi
# 0  ABSTRACT\r\n\r\nIn an effort to increase labor...  Manajemen
# 1  This study wanted to know the brand associatio...  Manajemen
# 2                                                NaN  Manajemen
# 3  Academic portal system in University of Trunoj...  Manajemen
# 4  Abstract\r\nThis research use quantitative met...  Manajemen
# 5  Abstract\r\n\r\nThis study is aimed to analyze...  Manajemen
# 6  ABSTRACT\r\n\r\nHaryono Arifin, Influence Cons...  Manajemen
# 7  ABSTRACT\r\n\r\nDharma Abidin Syah,Conclusions...  Manajemen
# 8  ABSTRACT\r\n\r\nThe purpose of this study was ...  Manajemen
# 9  Results from this study of Credit Risk Ratio c...  Manajemen
#
# Jumlah data: 1031

# %% [markdown]
# ## Preprocessing Crawling PTA

# %%
import pandas as pd
import re, string
from bs4 import BeautifulSoup
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from spellchecker import SpellChecker
from collections import Counter
from tqdm import tqdm

# Setup tqdm untuk apply pandas
tqdm.pandas()

# Kamus slang
contractions_dict = {
    "gak": "tidak", "ga": "tidak", "nggak": "tidak", "enggak": "tidak", "ngga": "tidak", "gk": "tidak",
    "gue": "saya", "gw": "saya", "gua": "saya", "lu": "kamu", "loe": "kamu",
    "dah": "sudah", "udah": "sudah", "aja": "saja", "yg": "yang", "utk": "untuk",
    "tp": "tetapi", "tapi": "tetapi", "bgt": "sekali", "lg": "lagi"
}

stop_words = set([
    "yang","di","ke","dan","dari","ini","itu","pada","untuk",
    "dengan","sebagai","adalah","merupakan","dalam","yaitu",
    "suatu","sebuah","akan","telah","bisa","agar","oleh",
    "bahwa","juga","atau","tidak","namun","tetapi","kemudian"
])

# Stemmer dan SpellChecker
factory = StemmerFactory()
stemmer = factory.create_stemmer()
spell = SpellChecker()

# --- Fungsi Preprocessing ---
def clean_base_text(text):
    if not isinstance(text, str): return ''
    text = text.lower()
    words = text.split()
    words = [contractions_dict.get(w, w) for w in words]
    text = ' '.join(words)
    text = re.sub(r'\d+', '', text)
    text = text.translate(str.maketrans('', '', string.punctuation))
    text = re.sub(r'\s+', ' ', text).strip()
    text = BeautifulSoup(text, "html.parser").get_text()
    return text

def tokenize(text): return text.split()
def remove_stopwords(tokens): return [w for w in tokens if w not in stop_words]
def stemming(tokens): return stemmer.stem(' '.join(tokens)).split()
def correct(tokens): return [spell.correction(w) or w for w in tokens]

# --- Main Preprocessing ---
def preprocess():
    print("📂 Membaca file CSV...")
    df = pd.read_csv("pta_manajemen_raw.csv")
    print(f"✅ Dataset terbaca, jumlah data: {len(df)} baris\n")

    print("🔄 Tahap 1: Cleaning...")
    df["abstrak_indonesia_clean"] = df["abstrak_indonesia"].progress_apply(clean_base_text)

    print("🔄 Tahap 2: Tokenizing...")
    df["abstrak_indonesia_tokens"] = df["abstrak_indonesia_clean"].progress_apply(tokenize)

    print("🔄 Tahap 3: Remove Stopwords...")
    df["abstrak_indonesia_stopwords"] = df["abstrak_indonesia_tokens"].progress_apply(remove_stopwords)

    print("🔄 Tahap 4: Stemming...")
    df["abstrak_indonesia_stemmed"] = df["abstrak_indonesia_stopwords"].progress_apply(stemming)

    print("🔄 Tahap 5: Spell Correction...")
    df["abstrak_indonesia_corrected"] = df["abstrak_indonesia_stemmed"].progress_apply(correct)

    print("🔄 Tahap 6: Hitung Frekuensi Kata...")
    df["frekuensi_kata_indonesia"] = df["abstrak_indonesia_stemmed"].progress_apply(lambda x: dict(Counter(x)))

    print("\n💾 Menyimpan hasil preprocessing ke pta_manajemen_preprocessed.csv...")
    df.to_csv("pta_manajemen_preprocessed.csv", index=False)
    print("✅ Preprocessing selesai.")

if __name__ == "__main__":
    preprocess()
# Out:
# 📂 Membaca file CSV...
# ✅ Dataset terbaca, jumlah data: 1031 baris
#
# 🔄 Tahap 1: Cleaning...
# 100%|████████████████████████████████████████████████████████████████████████████| 1031/1031 [00:00<00:00, 4258.63it/s]
# 🔄 Tahap 2: Tokenizing...
# 100%|███████████████████████████████████████████████████████████████████████████| 1031/1031 [00:00<00:00, 79988.30it/s]
# 🔄 Tahap 3: Remove Stopwords...
# 100%|███████████████████████████████████████████████████████████████████████████| 1031/1031 [00:00<00:00, 48555.21it/s]
# 🔄 Tahap 4: Stemming...
# 100%|██████████████████████████████████████████████████████████████████████████████| 1031/1031 [08:47<00:00,  1.96it/s]
# 🔄 Tahap 5: Spell Correction...
# 100%|████████████████████████████████████████████████████████████████████████████| 1031/1031 [8:41:51<00:00, 30.37s/it]
# 🔄 Tahap 6: Hitung Frekuensi Kata...
# 100%|███████████████████████████████████████████████████████████████████████████| 1031/1031 [00:00<00:00, 31355.93it/s]
# 💾 Menyimpan hasil preprocessing ke pta_manajemen_preprocessed.csv...
# ✅ Preprocessing selesai.

# %%
import pandas as pd

# baca file hasil preprocessing
df_pre = pd.read_csv("pta_manajemen_preprocessed.csv")

print("=== DATA HASIL PREPROCESSING ===")
print(df_pre.head(10))   # tampilkan 10 baris pertama
print("\nJumlah data:", len(df_pre))
# Out:
# === DATA HASIL PREPROCESSING ===
#                    penulis                                              judul  \
# 0                  SATIYAH  PENGARUH FAKTOR-FAKTOR PELATIHAN DAN PENGEMBAN...
# 1                  Faishal  ANALISIS PERSEPSI BRAND ASSOCIATION MENURUT PE...
# 2          Wahyu Kurniawan  PENGARUH GAYA KEPEMIMPINAN DEMOKRATIK TERHADAP...
# 3   Muhammad Zakaria Utomo  Pengukuran Website Quality Pada Situs Sistem A...
# 4  Hendri Wahyudi Prayitno  PENGARUH KEPEMIMPINAN DAN KOMPENSASI TERHADAP ...
# 5               Aththaariq  PENGARUH KOMPETENSI DOSEN TERHADAP KINERJA DOS...
# 6           Haryono Arifin  PENGARUH PERILAKU KONSUMEN TERHADAP KEPUTUSAN ...
# 7       Dharma Abidin Syah  PENGARUH TIPE KEPEMIMPINAN TERHADAP PRESTASI K...
# 8            Toni Budianto  PENGARUH DIMENSI KUALITAS PELAYANAN TERHADAP K...
# 9     Iwan Kurniawan Gomes  ANALISIS TINGKAT RISIKO KREDIT \r\nPADA PD. BP...
#
#                    pembimbing_pertama                        pembimbing_kedua  \
# 0  Dra. Hj. S. Anugrahini Irawati, MM         Helmi Buyung Aulia,S,ST.SE,M.MT
# 1                     Nurita Andriani                    Yustina Chrismardani
# 2      Dr. Dra. Hj. Iriani Ismail, MM      Dra. Hj. S. Anugrahini Irawati, MM
# 3         Dr. Ir. Nurita Andriani, MM               Nirma Kurriwati, SP, M.Si
# 4   Dra. Hj. S Anugrahini Irawati, MM          Helmi Buyung Aulia,S,ST,SE,.MT
# 5      Dr.RM Moch Wispandono,.S.E,.MS  Dr. Muhammad Alkirom Wildan,S.E.,M.Si.
# 6          Dr. Ir Nurita Andriani, MM             Nirma Kurriwati, S.P., M.Si
# 7      Drs. Ec. Mudji Kuswinarno M,Si                           Faidal SE, MM
# 8   Bambang Setiyo Pambudi, S.E., MM.                    Fathor AS, S.E., MM.
# 9     Drs. Ec. Makhmud Zulkifli, M.Si                 Echsan Gani, S.E., M.SI
#
#                                    abstrak_indonesia  \
# 0  ABSTRAK\r\nSatiyah, Pengaruh Faktor-faktor Pel...
# 1  Tujuan penelitian ini adalah untuk mengetahui ...
# 2                                                NaN
# 3  Aplikasi nyata pemanfaatan teknologi informasi...
# 4  Abstrak\r\nPenelitian ini menggunakan metode k...
# 5  Abstrak\r\n\r\nAththaariq, Pengaruh Kompetensi...
# 6  ABSTRAK\r\nHaryono Arifin, Pengaruh Perilaku K...
# 7  ABSTRAK\r\n\tDharma Abidin Syah,Kesimpulan: (1...
# 8  ABSTRAK\r\n\r\nTujuan penelitian ini adalah un...
# 9  Hasil dari penelitian ini dari perhitungan Cre...
#
#                                      abstrak_inggris      prodi  \
# 0  ABSTRACT\r\n\r\nIn an effort to increase labor...  Manajemen
# 1  This study wanted to know the brand associatio...  Manajemen
# 2                                                NaN  Manajemen
# 3  Academic portal system in University of Trunoj...  Manajemen
# 4  Abstract\r\nThis research use quantitative met...  Manajemen
# 5  Abstract\r\n\r\nThis study is aimed to analyze...  Manajemen
# 6  ABSTRACT\r\n\r\nHaryono Arifin, Influence Cons...  Manajemen
# 7  ABSTRACT\r\n\r\nDharma Abidin Syah,Conclusions...  Manajemen
# 8  ABSTRACT\r\n\r\nThe purpose of this study was ...  Manajemen
# 9  Results from this study of Credit Risk Ratio c...  Manajemen
#
#                              abstrak_indonesia_clean  \
# 0  abstrak satiyah pengaruh faktorfaktor pelatiha...
# 1  tujuan penelitian ini adalah untuk mengetahui ...
# 2                                                NaN
# 3  aplikasi nyata pemanfaatan teknologi informasi...
# 4  abstrak penelitian ini menggunakan metode kuan...
# 5  abstrak aththaariq pengaruh kompetensi dosen t...
# 6  abstrak haryono arifin pengaruh perilaku konsu...
# 7  abstrak dharma abidin syahkesimpulan terdapat ...
# 8  abstrak tujuan penelitian ini adalah untuk men...
# 9  hasil dari penelitian ini dari perhitungan cre...
#
#                             abstrak_indonesia_tokens  \
# 0  ['abstrak', 'satiyah', 'pengaruh', 'faktorfakt...
# 1  ['tujuan', 'penelitian', 'ini', 'adalah', 'unt...
# 2                                                 []
# 3  ['aplikasi', 'nyata', 'pemanfaatan', 'teknolog...
# 4  ['abstrak', 'penelitian', 'ini', 'menggunakan'...
# 5  ['abstrak', 'aththaariq', 'pengaruh', 'kompete...
# 6  ['abstrak', 'haryono', 'arifin', 'pengaruh', '...
# 7  ['abstrak', 'dharma', 'abidin', 'syahkesimpula...
# 8  ['abstrak', 'tujuan', 'penelitian', 'ini', 'ad...
# 9  ['hasil', 'dari', 'penelitian', 'ini', 'dari',...
#
#                          abstrak_indonesia_stopwords  \
# 0  ['abstrak', 'satiyah', 'pengaruh', 'faktorfakt...
# 1  ['tujuan', 'penelitian', 'mengetahui', 'persep...
# 2                                                 []
# 3  ['aplikasi', 'nyata', 'pemanfaatan', 'teknolog...
# 4  ['abstrak', 'penelitian', 'menggunakan', 'meto...
# 5  ['abstrak', 'aththaariq', 'pengaruh', 'kompete...
# 6  ['abstrak', 'haryono', 'arifin', 'pengaruh', '...
# 7  ['abstrak', 'dharma', 'abidin', 'syahkesimpula...
# 8  ['abstrak', 'tujuan', 'penelitian', 'mengident...
# 9  ['hasil', 'penelitian', 'perhitungan', 'credit...
#
#                            abstrak_indonesia_stemmed  \
# 0  ['abstrak', 'satiyah', 'pengaruh', 'faktorfakt...
# 1  ['tuju', 'teliti', 'tahu', 'persepsi', 'brand'...
# 2                                                 []
# 3  ['aplikasi', 'nyata', 'manfaat', 'teknologi', ...
# 4  ['abstrak', 'teliti', 'guna', 'metode', 'kuant...
# 5  ['abstrak', 'aththaariq', 'pengaruh', 'kompete...
# 6  ['abstrak', 'haryono', 'arifin', 'pengaruh', '...
# 7  ['abstrak', 'dharma', 'abidin', 'syahkesimpula...
# 8  ['abstrak', 'tuju', 'teliti', 'identifikasi', ...
# 9  ['hasil', 'teliti', 'hitung', 'credit', 'risk'...
#
#                          abstrak_indonesia_corrected  \
# 0  ['abstract', 'aaliyah', 'pengaruh', 'faktorfak...
# 1  ['juju', 'elite', 'tau', 'perseus', 'brand', '...
# 2                                                 []
# 3  ['aplikasi', 'nyala', 'manat', 'teknologi', 'i...
# 4  ['abstract', 'elite', 'gun', 'metope', 'kuanti...
# 5  ['abstract', 'aththaariq', 'pengaruh', 'kompet...
# 6  ['abstract', 'harmony', 'origin', 'pengaruh', ...
# 7  ['abstract', 'dharma', 'abiding', 'syahkesimpu...
# 8  ['abstract', 'juju', 'elite', 'identifikasi', ...
# 9  ['hail', 'elite', 'hiding', 'credit', 'risk', ...
#
#                             frekuensi_kata_indonesia
# 0  {'abstrak': 1, 'satiyah': 1, 'pengaruh': 5, 'f...
# 1  {'tuju': 1, 'teliti': 5, 'tahu': 1, 'persepsi'...
# 2                                                 {}
# 3  {'aplikasi': 1, 'nyata': 1, 'manfaat': 1, 'tek...
# 4  {'abstrak': 1, 'teliti': 4, 'guna': 3, 'metode...
# 5  {'abstrak': 1, 'aththaariq': 1, 'pengaruh': 6,...
# 6  {'abstrak': 1, 'haryono': 1, 'arifin': 1, 'pen...
# 7  {'abstrak': 1, 'dharma': 1, 'abidin': 1, 'syah...
# 8  {'abstrak': 1, 'tuju': 1, 'teliti': 2, 'identi...
# 9  {'hasil': 1, 'teliti': 2, 'hitung': 1, 'credit...
#
# Jumlah data: 1031

# %% [markdown]
# ## Page & Link Keluar PTA

# %%
import urllib3
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import pandas as pd

# matikan warning SSL insecure
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

def scrape_all_links(base_url, max_pages=50):
    visited = set()
    results = []

    def scrape_page(url):
        try:
            response = requests.get(url, verify=False, timeout=10)
            soup = BeautifulSoup(response.text, 'html.parser')

            # ambil semua link keluar
            for a in soup.find_all('a', href=True):
                href = a['href'].strip()
                if not href or href == "#":
                    continue
                full_link = urljoin(url, href)
                results.append({
                    "Page": url,
                    "Link Keluar": full_link
                })

            # cari link internal untuk dilanjutkan
            for a in soup.find_all('a', href=True):
                href = a['href'].strip()
                if not href or href == "#":
                    continue
                full_link = urljoin(url, href)
                # hanya ambil link internal (masih di domain utama)
                if full_link.startswith(base_url) and full_link not in visited:
                    visited.add(full_link)
                    if len(visited) < max_pages:
                        scrape_page(full_link)

        except Exception as e:
            print(f"⚠️ Gagal akses {url}: {e}")

    # mulai dari base_url
    visited.add(base_url)
    scrape_page(base_url)

    # rapikan dataframe
    df = pd.DataFrame(results).reset_index(drop=True)
    df.index += 1
    df.insert(0, "No", df.index)
    return df

# contoh penggunaan
url = "https://manajemen.trunojoyo.ac.id/"
df_links = scrape_all_links(url, max_pages=30)  # max_pages = batas biar ga infinite loop

df_links
# df_links.to_csv("semua_link.csv", index=False, encoding="utf-8-sig")
# Out:
#         No                                               Page  \
# 1        1                 https://manajemen.trunojoyo.ac.id/
# 2        2                 https://manajemen.trunojoyo.ac.id/
# 3        3                 https://manajemen.trunojoyo.ac.id/
# 4        4                 https://manajemen.trunojoyo.ac.id/
# 5        5                 https://manajemen.trunojoyo.ac.id/
# ...    ...                                                ...
# 2469  2469  https://manajemen.trunojoyo.ac.id/kalender-aka...
# 2470  2470  https://manajemen.trunojoyo.ac.id/kalender-aka...
# 2471  2471  https://manajemen.trunojoyo.ac.id/kalender-aka...
# 2472  2472  https://manajemen.trunojoyo.ac.id/kalender-aka...
# 2473  2473  https://manajemen.trunojoyo.ac.id/kalender-aka...
#
#                                             Link Keluar
# 1            https://manajemen.trunojoyo.ac.id/#content
# 2                                      tel:082330605254
# 3                      mailto:manajemen@trunojoyo.ac.id
# 4                    https://manajemen.trunojoyo.ac.id/
# 5                    https://manajemen.trunojoyo.ac.id/
# ...                                                 ...
# 2469  https://manajemen.trunojoyo.ac.id/visit-compan...
# 2470  https://manajemen.trunojoyo.ac.id/internationa...
# 2471                             https://wordpress.org/
# 2472                             https://wenthemes.com/
# 2473  https://manajemen.trunojoyo.ac.id/kalender-aka...
#
# [2473 rows x 3 columns]

# %% [markdown]
# ## Preprocessing Berita

# %%
import pandas as pd
import re
import string
import sys
import time
import random
from collections import Counter
from tqdm import tqdm
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from spellchecker import SpellChecker
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# ===============================
# KONFIGURASI PREPROCESSING
# ===============================

# Kamus normalisasi kata tidak baku → baku
contractions_dict = {
    "gak": "tidak", "ga": "tidak", "nggak": "tidak", "enggak": "tidak", "ngga": "tidak", "gk": "tidak",
    "gue": "saya", "gw": "saya", "gua": "saya", "lu": "kamu", "loe": "kamu",
    "dah": "sudah", "udah": "sudah", "aja": "saja", "ajah": "saja",
    "yg": "yang", "utk": "untuk", "dlm": "dalam", "dr": "dari", "dg": "dengan",
    "jd": "jadi", "krn": "karena", "tp": "tetapi", "tapi": "tetapi",
    "banget": "sekali", "bgt": "sekali", "lg": "lagi",
}

# Inisialisasi alat bantu preprocessing
stemmer = StemmerFactory().create_stemmer()
spell = SpellChecker()
stopword_remover = StopWordRemoverFactory().create_stop_word_remover()


# ===============================
# FUNGSI-FUNGSI PREPROCESSING
# ===============================

def clean_base_text(text):
    """Membersihkan teks dari angka, simbol, dan mengganti slang."""
    if not isinstance(text, str):
        return ''
    words = text.split()
    expanded_words = [contractions_dict.get(word.lower(), word) for word in words]
    text = ' '.join(expanded_words)
    text = re.sub(r'\d+', '', text)
    text = text.lower()
    text = text.translate(str.maketrans('', '', string.punctuation))
    text = re.sub(r'\s+', ' ', text).strip()
    return text


def tokenize_text(text):
    """Tokenisasi teks menjadi daftar kata."""
    return text.split()


def remove_stopwords(tokens):
    """Menghapus kata umum (stopwords)."""
    text = ' '.join(tokens)
    text = stopword_remover.remove(text)
    return text.split()


def apply_stemming(tokens):
    """Melakukan stemming (mengubah ke kata dasar)."""
    text = ' '.join(tokens)
    stemmed_text = stemmer.stem(text)
    return stemmed_text.split()


def correct_spelling(tokens):
    """Melakukan pembetulan ejaan kata menggunakan SpellChecker."""
    corrected = [spell.correction(word) if spell.correction(word) else word for word in tokens]
    return corrected


# ===============================
# FUNGSI UTAMA PREPROCESSING
# ===============================

def preprocessing_berita(input_file="crawling_detik_berita.csv", output_file="hasil_preprocessing_berita.csv"):
    print("📥 Membaca data dari file:", input_file)
    df = pd.read_csv(input_file)
    print(f"✅ Data berhasil dimuat. Total {len(df)} baris.\n")

    processed_data = []
    start_time = time.time()

    # Gunakan tqdm untuk progress bar
    for idx, row in tqdm(df.iterrows(), total=len(df), desc="🔄 Memproses Berita", ncols=90):
        content = str(row.get("isi_berita_original", ""))
        title = str(row.get("judul_berita", ""))
        category = str(row.get("kategori_berita", ""))

        if not content.strip():
            continue

        # === Tahapan preprocessing ===
        clean_text = clean_base_text(content)
        tokens = tokenize_text(clean_text)
        stop_removed = remove_stopwords(tokens)
        stemmed = apply_stemming(stop_removed)
        corrected = correct_spelling(stemmed)
        freq = Counter(corrected)

        processed_data.append({
            "id_berita": row.get("id_berita"),
            "judul_berita": title,
            "kategori_berita": category,
            "isi_berita_original": content,
            "isi_berita_bersih": clean_text,
            "isi_berita_diproses": ' '.join(corrected),
            "jumlah_kata": len(corrected),
            "frekuensi_kata": dict(freq)
        })

        time.sleep(random.uniform(0.1, 0.3))  # jeda kecil agar progress bar smooth

    result_df = pd.DataFrame(processed_data)
    result_df.to_csv(output_file, index=False, encoding="utf-8-sig")

    end_time = time.time()
    elapsed = int(end_time - start_time)
    menit, detik = divmod(elapsed, 60)
    print(f"\n✅ Preprocessing selesai!")
    print(f"📊 Total berita diproses: {len(result_df)}")
    print(f"💾 File hasil disimpan sebagai: {output_file}")
    print(f"⏱️ Durasi: {menit} menit {detik} detik")
    print("\n📌 Contoh hasil 5 berita pertama:")
    print(result_df.head())

    return result_df


# ===============================
# EKSEKUSI
# ===============================
if __name__ == "__main__":
    preprocessing_berita()
# Out:
# 📥 Membaca data dari file: crawling_detik_berita.csv
# ✅ Data berhasil dimuat. Total 701 baris.
# 🔄 Memproses Berita: 100%|███████████████████████████| 701/701 [10:35:37<00:00, 54.40s/it]
# ✅ Preprocessing selesai!
# 📊 Total berita diproses: 701
# 💾 File hasil disimpan sebagai: hasil_preprocessing_berita.csv
# ⏱️ Durasi: 635 menit 37 detik
#
# 📌 Contoh hasil 5 berita pertama:
#    id_berita                                       judul_berita  \
# 0    8158197  Pria di Bekasi Curi Kabel Rel KA, KAI Ungkap R...
# 1    8158178  3 Pelaku Ditangkap Terkait 2 Orang di Kintaman...
# 2    8158168  Bripda Aprilia Eka Raih Medali Emas di Uzbekis...
# 3    8158166  DKI Gratiskan Layanan Angkut Sampah Besar, War...
# 4    8158148  Video Call Terakhir Letda Fauzy dengan Ayah Se...
#
#   kategori_berita                                isi_berita_original  \
# 0         politik  Petugas pengamanan (PAM) PT Kereta Api Indones...
# 1         politik  Polisi telah mengamankan tiga orang dari perke...
# 2         politik  Bripda Aprilia Eka Putri Lumbantungkup menjuar...
# 3         politik  Pemerintah Provinsi DKI Jakartakini menggratis...
# 4         politik  Perwira muda TNI AD, Letda Inf Fauzy Ahmad Sul...
#
#                                    isi_berita_bersih  \
# 0  petugas pengamanan pam pt kereta api indonesia...
# 1  polisi telah mengamankan tiga orang dari perke...
# 2  bripda aprilia eka putri lumbantungkup menjuar...
# 3  pemerintah provinsi dki jakartakini menggratis...
# 4  perwira muda tni ad letda inf fauzy ahmad sulk...
#
#                                  isi_berita_diproses  jumlah_kata  \
# 0  tugs man pam pt hereto ape indonesia ai tanka ...          351
# 1  polish man toga orang delhi mat jade banner ta...          172
# 2  bride april era putrid lumbantungkup juana uzb...          171
# 3  perineal proving ski jakartakini gratis layman...          251
# 4  persia mud tin ad leda inf gauzy ahmad sulkarn...          157
#
#                                       frekuensi_kata
# 0  {'tugs': 5, 'man': 8, 'pam': 3, 'pt': 1, 'here...
# 1  {'polish': 1, 'man': 2, 'toga': 1, 'orang': 4,...
# 2  {'bride': 4, 'april': 4, 'era': 1, 'putrid': 1...
# 3  {'perineal': 1, 'proving': 1, 'ski': 2, 'jakar...
# 4  {'persia': 1, 'mud': 2, 'tin': 1, 'ad': 1, 'le...
