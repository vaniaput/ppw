# %% [markdown]
# # **Crawwling X Hastag dan Keyword**

# %% [markdown]
# # Code Crawwling X Hastag dan Keyword

# %%
#@title Twitter Auth Token

twitter_auth_token = 'd88ee088fb80eeac1189a51b5f69f67d2ffb1f80' # change this auth token

# %%
# Import required Python package
# !pip install pandas

# Install Node.js (because tweet-harvest built using Node.js)
# !sudo apt-get update
# !sudo apt-get install -y ca-certificates curl gnupg libatk1.0-0 libgtk-3-0
# !sudo mkdir -p /etc/apt/keyrings
# !curl -fsSL https://deb.nodesource.com/gpgkey/nodesource-repo.gpg.key | sudo gpg --dearmor -o /etc/apt/keyrings/nodesource.gpg

# !NODE_MAJOR=20 && echo "deb [signed-by=/etc/apt/keyrings/nodesource.gpg] https://deb.nodesource.com/node_$NODE_MAJOR.x nodistro main" | sudo tee /etc/apt/sources.list.d/nodesource.list

# !sudo apt-get update
# !sudo apt-get install nodejs -y

# !node -v
# Out:
# ...
# Hit:1 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:2 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:3 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:4 https://cli.github.com/packages stable InRelease
# Hit:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:6 https://deb.nodesource.com/node_20.x nodistro InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:8 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:9 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:12 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# ...

# %% [markdown]
# ## Crawling Hastag

# %%
# Crawl Data

filename = 'hastagcrwl.csv'
search_keyword = '#SumateraPrioritasNasional lang:id'
limit = 500

# !npx -y tweet-harvest@2.6.1 -o "{filename}" -s "{search_keyword}" --tab "LATEST" -l {limit} --token {twitter_auth_token}
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇Tweet Harvest [v2.6.1]
#
# Research by Helmi Satria
# Use it for Educational Purposes only!
#
# This script uses Chromium Browser to crawl data from Twitter with your Twitter auth token.
# Please enter your Twitter auth token when prompted.
#
# Note: Keep your access token secret! Don't share it with anyone else.
# Note: This script only runs on your local device.
#
#
# Opening twitter search page...
#
#
# Found existing file ./tweets-data/hastagcrwl.csv, renaming to ./tweets-data/hastagcrwl.old.csv
#
# -- Scrolling... (1) (2) (3)
# Filling in keywords: #SumateraPrioritasNasional lang:id
#
#  (4)
#
# Your tweets saved to: /content/tweets-data/hastagcrwl.csv
# Total tweets saved: 15
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/hastagcrwl.csv
# Total tweets saved: 29
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/hastagcrwl.csv
# Total tweets saved: 42
#
# -- Scrolling... (1)
#
# ...

# %% [markdown]
# ## Menampilkan Data Crawling Hastag

# %%
import pandas as pd

# Specify the path to your CSV file
file_path = f"tweets-data/hastagcrwl.csv"

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(file_path, delimiter=",")

# Display the DataFrame
display(df)
# Out:
#      conversation_id_str                      created_at  favorite_count  \
# 0    1996422417137422631  Thu Dec 04 03:32:50 +0000 2025               0
# 1    1996422396035895676  Thu Dec 04 03:32:45 +0000 2025               0
# 2    1996422379128680611  Thu Dec 04 03:32:41 +0000 2025               0
# 3    1996422376108790107  Thu Dec 04 03:32:40 +0000 2025               0
# 4    1996422260559941685  Thu Dec 04 03:32:13 +0000 2025               0
# ..                   ...                             ...             ...
# 496  1996413704649519356  Thu Dec 04 02:58:13 +0000 2025               0
# 497  1996413695757586735  Thu Dec 04 02:58:11 +0000 2025               0
# 498  1996413691634598035  Thu Dec 04 02:58:10 +0000 2025               0
# 499  1996413688392335483  Thu Dec 04 02:58:09 +0000 2025               0
# 500  1996413685716422845  Thu Dec 04 02:58:08 +0000 2025               0
#
#                                              full_text               id_str  \
# ...

# %% [markdown]
# ## Jumlah Data Hastag Yang Di Dapatkan

# %%
# Cek jumlah data yang didapatkan

num_tweets = len(df)
print(f"Jumlah tweet dalam dataframe adalah {num_tweets}.")
# Out:
# Jumlah tweet dalam dataframe adalah 501.

# %% [markdown]
# ## Crawling Keyword

# %%
# Crawl Data

filename = 'keywordcrwl.csv'
search_keyword = 'bencana lang:id'
limit = 500

# !npx -y tweet-harvest@2.6.1 -o "{filename}" -s "{search_keyword}" --tab "LATEST" -l {limit} --token {twitter_auth_token}
# Out:
# ⠙⠹⠸⠼⠴⠦⠧Tweet Harvest [v2.6.1]
#
# Research by Helmi Satria
# Use it for Educational Purposes only!
#
# This script uses Chromium Browser to crawl data from Twitter with your Twitter auth token.
# Please enter your Twitter auth token when prompted.
#
# Note: Keep your access token secret! Don't share it with anyone else.
# Note: This script only runs on your local device.
#
#
# Opening twitter search page...
#
#
# -- Scrolling... (1) (2) (3)
# Filling in keywords: bencana lang:id
#
#  (4)
#
# Your tweets saved to: /content/tweets-data/keywordcrwl.csv
# Total tweets saved: 20
#
# -- Scrolling... (1) (2) (3) (4) (5) (6)
#
# Your tweets saved to: /content/tweets-data/keywordcrwl.csv
# Total tweets saved: 40
#
# -- Scrolling... (1) (2) (3) (4) (5)
#
# Your tweets saved to: /content/tweets-data/keywordcrwl.csv
# Total tweets saved: 59
#
# -- Scrolling... (1) (2) (3) (4) (5)
#
# Your tweets saved to: /content/tweets-data/keywordcrwl.csv
# Total tweets saved: 78
#
# -- Scrolling... (1) (2)
# ...

# %% [markdown]
# ## Menampilkan Data Crawling Keyword

# %%
import pandas as pd

# Specify the path to your CSV file
file_path = f"tweets-data/keywordcrwl.csv"

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(file_path, delimiter=",")

# Display the DataFrame
display(df)
# Out:
#      conversation_id_str                      created_at  favorite_count  \
# 0    1996423505844527313  Thu Dec 04 03:37:10 +0000 2025               0
# 1    1996423505039208843  Thu Dec 04 03:37:10 +0000 2025               0
# 2    1996423504577888682  Thu Dec 04 03:37:09 +0000 2025               0
# 3    1996423497913167905  Thu Dec 04 03:37:08 +0000 2025               0
# 4    1996423491772612905  Thu Dec 04 03:37:06 +0000 2025               0
# ..                   ...                             ...             ...
# 508  1996421144224920005  Thu Dec 04 03:27:47 +0000 2025               0
# 509  1996421139946680632  Thu Dec 04 03:27:46 +0000 2025               0
# 510  1996421135932723408  Thu Dec 04 03:27:45 +0000 2025               1
# 511  1996421135131717703  Thu Dec 04 03:27:44 +0000 2025               0
# 512  1996421130442404172  Thu Dec 04 03:27:43 +0000 2025               0
#
#                                              full_text               id_str  \
# ...

# %% [markdown]
# ## Jumlah Data Keyword Yang Di Dapatkan

# %%
# Cek jumlah data yang didapatkan

num_tweets = len(df)
print(f"Jumlah tweet dalam dataframe adalah {num_tweets}.")
# Out:
# Jumlah tweet dalam dataframe adalah 513.
